# %% [markdown]
# # ETL Project: Leading causes of death in the United States
#
# #### Aim:
# An analysis on the leading causes of death in the United States. This case study seeks to analyze the top causes of deaths from 2013 to 2016 by ranking death causes by year, state, and age-adjusted death rates. Further, would U.S. chronic disease indicators provide any insight into risk factors that may be associated with those leading causes of death?
#
# #### Notes:
# The 10 leading causes of death are classified by the International Classification of Diseases, Tenth Revision (ICD-10). Age-adjusted death rates are per 100,000 population.
#
#
# #### Data provided by:
# * [CDC/HCHS](https://catalog.data.gov/dataset/age-adjusted-death-rates-for-the-top-10-leading-causes-of-death-united-states-2013)
#
# * [CDC](https://catalog.data.gov/dataset/u-s-chronic-disease-indicators-cdi)

# %%
# import dependencies
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
# read csv file for data on leading causes of death
leading_causes_death_df = pd.read_csv('Resources/NCHS_-_Leading_Causes_of_Death__United_States.csv')

# %%
# preview the dataframe created
leading_causes_death_df.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
## cleaning the database

# Remove cause_name and state columns, Rename columns into a new dataframe
leading_causes = leading_causes_death_df[['Year', '113 Cause Name', 'State','Deaths', 'Age-adjusted Death Rate']].copy()
leading_causes = leading_causes.rename(columns={
    "Year":"year",
    "113 Cause Name": "cause_name",
    "State": "state",
    "Deaths": "deaths",
    "Age-adjusted Death Rate": "age-ajusted_death_rate"
})
leading_causes.sort_values(by=["year"]).head()
# Out:
#        year                                         cause_name          state  \
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...        Wyoming
# 1418   1999                          Alzheimer's disease (G30)      Minnesota
# 8726   1999  Intentional self-harm (suicide) (*U03,X60-X84,...       Illinois
# 7016   1999  Nephritis, nephrotic syndrome and nephrosis (N...       Michigan
# 4334   1999                        Diabetes mellitus (E10-E14)  New Hampshire
#
#        deaths  age-ajusted_death_rate
# 10295     258                    52.8
# 1418     1083                    21.1
# 8726     1020                     8.3
# 7016     1417                    15.0
# 4334      294                    25.3

# %%
# Filter leading_causes for years >=2013
leading_causes_2013_to_2016 = leading_causes.loc[leading_causes['year'] >= 2013,:]
leading_causes_2013_to_2016=leading_causes_2013_to_2016.sort_values(by=['year'])

#### PUT THIS DATAFRAME INTO THE DATABASE
leading_causes_2013_to_2016.head()
# Out:
#        year                                         cause_name          state  \
# 10281  2013  Accidents (unintentional injuries) (V01-X59,Y8...        Wyoming
# 3708   2013       Chronic lower respiratory diseases (J40-J47)       Virginia
# 3726   2013       Chronic lower respiratory diseases (J40-J47)     Washington
# 8946   2013  Intentional self-harm (suicide) (*U03,X60-X84,...        Montana
# 3744   2013       Chronic lower respiratory diseases (J40-J47)  West Virginia
#
#        deaths  age-ajusted_death_rate
# 10281     325                    55.2
# 3708     3181                    37.3
# 3726     2933                    39.4
# 8946      243                    23.7
# 3744     1590                    64.6

# %%
# # Group dataframe by year and cause_name, finding the sum of deaths 
# leading_causes_2013_to_2016_grouped=leading_causes_2013_to_2016.groupby(["year", "cause_name"]).sum().copy()
# leading_causes_2013_to_2016_grouped.head()

# %% [markdown]
# ## Connect to MySQL database

# %%
#engine = create_engine("mysql://root:Codingislife92!@localhost:3306/leading_causes_of_death_db")
pymysql.install_as_MySQLdb()
connection_string = "root:bdasl2019@127.0.0.1/leading_causes_of_death_db"
engine = create_engine(f'mysql://{connection_string}')

# %%
leading_causes_2013_to_2016.to_sql(name='leading_causes', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('SELECT * FROM leading_causes', con=engine).head()
# Out:
#    year                                         cause_name          state  \
# 0  2013  Accidents (unintentional injuries) (V01-X59,Y8...        Wyoming
# 1  2013       Chronic lower respiratory diseases (J40-J47)       Virginia
# 2  2013       Chronic lower respiratory diseases (J40-J47)     Washington
# 3  2013  Intentional self-harm (suicide) (*U03,X60-X84,...        Montana
# 4  2013       Chronic lower respiratory diseases (J40-J47)  West Virginia
#
#    deaths  age-ajusted_death_rate
# 0     325                    55.2
# 1    3181                    37.3
# 2    2933                    39.4
# 3     243                    23.7
# 4    1590                    64.6

# %%
engine.table_names()
# Out:
# ['leading_causes']

# %%
# QUERY TO SUM DEATHS, GROUPED BY YEAR AND CAUSE OF DEATH

pd.read_sql_query('SELECT year, cause_name,\
                  SUM(deaths) as total_US_deaths\
                  FROM leading_causes\
                  GROUP BY year, cause_name\
                  HAVING year >= 2013\
                  ORDER BY year ASC', con=engine)
# Out:
#     year                                         cause_name  total_US_deaths
# 0   2013  Accidents (unintentional injuries) (V01-X59,Y8...        1305570.0
# 1   2013                                         All Causes       25969930.0
# 2   2013                          Alzheimer's disease (G30)         847670.0
# 3   2013                 Cerebrovascular diseases (I60-I69)        1289780.0
# 4   2013       Chronic lower respiratory diseases (J40-J47)        1492050.0
# 5   2013                        Diabetes mellitus (E10-E14)         755780.0
# 6   2013        Diseases of heart (I00-I09,I11,I13,I20-I51)        6111050.0
# 7   2013                  Influenza and pneumonia (J09-J18)         569790.0
# 8   2013  Intentional self-harm (suicide) (*U03,X60-X84,...         411490.0
# 9   2013                      Malignant neoplasms (C00-C97)        5848810.0
# 10  2013  Nephritis, nephrotic syndrome and nephrosis (N...         471120.0
# 11  2014  Accidents (unintentional injuries) (V01-X59,Y8...        1359280.0
# 12  2014                                         All Causes       26264180.0
# 13  2014                          Alzheimer's disease (G30)         935410.0
# 14  2014                 Cerebrovascular diseases (I60-I69)        1331030.0
# 15  2014       Chronic lower respiratory diseases (J40-J47)        1471010.0
# 16  2014                        Diabetes mellitus (E10-E14)         764880.0
# 17  2014        Diseases of heart (I00-I09,I11,I13,I20-I51)        6143480.0
# 18  2014                  Influenza and pneumonia (J09-J18)         552270.0
# 19  2014  Intentional self-harm (suicide) (*U03,X60-X84,...         428260.0
# 20  2014                      Malignant neoplasms (C00-C97)        5917000.0
# 21  2014  Nephritis, nephrotic syndrome and nephrosis (N...         481460.0
# 22  2015  Accidents (unintentional injuries) (V01-X59,Y8...        1465710.0
# 23  2015                                         All Causes       27126300.0
# 24  2015                          Alzheimer's disease (G30)        1105610.0
# 25  2015                 Cerebrovascular diseases (I60-I69)        1403230.0
# 26  2015       Chronic lower respiratory diseases (J40-J47)        1550410.0
# 27  2015                        Diabetes mellitus (E10-E14)         795350.0
# 28  2015        Diseases of heart (I00-I09,I11,I13,I20-I51)        6338420.0
# 29  2015                  Influenza and pneumonia (J09-J18)         570620.0
# 30  2015  Intentional self-harm (suicide) (*U03,X60-X84,...         441930.0
# 31  2015                      Malignant neoplasms (C00-C97)        5959300.0
# 32  2015  Nephritis, nephrotic syndrome and nephrosis (N...         499590.0
# 33  2016  Accidents (unintentional injuries) (V01-X59,Y8...        1613740.0
# 34  2016                                         All Causes       25318615.0
# 35  2016                          Alzheimer's disease (G30)        1161030.0
# 36  2016                 Cerebrovascular diseases (I60-I69)        1421420.0
# 37  2016       Chronic lower respiratory diseases (J40-J47)        1545960.0
# 38  2016                        Diabetes mellitus (E10-E14)         800580.0
# 39  2016        Diseases of heart (I00-I09,I11,I13,I20-I51)        6352600.0
# 40  2016                  Influenza and pneumonia (J09-J18)         515370.0
# 41  2016  Intentional self-harm (suicide) (*U03,X60-X84,...         449650.0
# 42  2016                      Malignant neoplasms (C00-C97)        5980380.0
# 43  2016  Nephritis, nephrotic syndrome and nephrosis (N...         500460.0

# %% [markdown]
# ## NCHS Leading Causes of Death by State

# %%
# Deaths per state
state_deaths = pd.read_sql_query('SELECT state, deaths as total_state_deaths \
                FROM leading_causes', con=engine)
deaths_state = state_deaths.groupby(['state'])
deaths_state_df = deaths_state['total_state_deaths'].sum()
deaths_state_df.sort_values(ascending=False)
# Out:
# state
# United States           90756855
# California               8986635
# Florida                  6602975
# Texas                    6417540
# New York                 5337340
# Pennsylvania             4530500
# Ohio                     4050965
# Illinois                 3675160
# Michigan                 3324315
# North Carolina           3008225
# Georgia                  2703585
# New Jersey               2488580
# Tennessee                2297305
# Virginia                 2221955
# Indiana                  2147075
# Missouri                 2075190
# Massachusetts            1904690
# Arizona                  1854480
# Washington               1852165
# Alabama                  1776320
# Wisconsin                1767615
# Maryland                 1602360
# South Carolina           1601570
# Kentucky                 1598475
# Louisiana                1529915
# Minnesota                1431975
# Oklahoma                 1377770
# Colorado                 1232825
# Oregon                   1193275
# Mississippi              1099250
# Arkansas                 1096555
# Connecticut              1030335
# Iowa                     1023660
# Kansas                    893715
# Nevada                    799060
# West Virginia             776500
# New Mexico                604330
# Utah                      582330
# Nebraska                  552580
# Maine                     480965
# Idaho                     444975
# New Hampshire             403225
# Hawaii                    375960
# Rhode Island              341025
# Montana                   333665
# Delaware                  293450
# South Dakota              266455
# North Dakota              216185
# Vermont                   201345
# District of Columbia      166270
# Wyoming                   162355
# Alaska                    145750
# Name: total_state_deaths, dtype: int64

# %%
# Deaths in each state per cause per year
state_deaths = pd.read_sql_query('SELECT state, cause_name, year, deaths as total_state_deaths \
                FROM leading_causes', con=engine)
deaths_state = state_deaths.groupby(['state', 'cause_name', 'year'])
deaths_state_df = deaths_state['total_state_deaths'].sum()
print(deaths_state_df.sort_values)
# Out:
# <bound method Series.sort_values of state    cause_name                                                             year
# Alabama  Accidents (unintentional injuries) (V01-X59,Y85-Y86)                   2013     11645
#                                                                                 2014     12315
#                                                                                 2015     12760
#                                                                                 2016     13775
#          All Causes                                                             2013    250945
#                                                                                 2014    251075
#                                                                                 2015    259545
#                                                                                 2016    262330
#          Alzheimer's disease (G30)                                              2013      6990
#                                                                                 2014      9425
#                                                                                 2015     11410
#                                                                                 2016     12535
#          Cerebrovascular diseases (I60-I69)                                     2013     13020
#                                                                                 2014     13315
#                                                                                 2015     14685
#                                                                                 2016     14835
#          Chronic lower respiratory diseases (J40-J47)                           2013     15215
#                                                                                 2014     15250
#                                                                                 2015     16395
#                                                                                 2016     16630
#          Diabetes mellitus (E10-E14)                                            2013      6745
#                                                                                 2014      6405
#                                                                                 2015      6275
#                                                                                 2016      5915
#          Diseases of heart (I00-I09,I11,I13,I20-I51)                            2013     62360
#                                                                                 2014     62305
#                                                                                 2015     64905
#                                                                                 2016     64160
#          Influenza and pneumonia (J09-J18)                                      2013      5175
#                                                                                 2014      5155
#                                                                                          ...
# Wyoming  Cerebrovascular diseases (I60-I69)                                     2015       990
#                                                                                 2016      1040
#          Chronic lower respiratory diseases (J40-J47)                           2013      1935
#                                                                                 2014      1715
#                                                                                 2015      1840
#                                                                                 2016      1635
#          Diabetes mellitus (E10-E14)                                            2013       445
#                                                                                 2014       550
#                                                                                 2015       680
#                                                                                 2016       560
#          Diseases of heart (I00-I09,I11,I13,I20-I51)                            2013      4695
#                                                                                 2014      5175
#                                                                                 2015      5150
#                                                                                 2016      5255
#          Influenza and pneumonia (J09-J18)                                      2013       560
#                                                                                 2014       565
#                                                                                 2015       495
#                                                                                 2016       495
#          Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                   2013       645
#                                                                                 2014       600
#                                                                                 2015       785
#                                                                                 2016       720
#          Malignant neoplasms (C00-C97)                                          2013      4730
#                                                                                 2014      4610
#                                                                                 2015      4655
#                                                                                 2016      4810
#          Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)  2013       280
#                                                                                 2014       390
#                                                                                 2015       430
#                                                                                 2016       330
# Name: total_state_deaths, Length: 2288, dtype: int64>

# %%
# Deaths per cause
state_causes = pd.read_sql_query('SELECT cause_name, deaths as total_state_deaths \
                FROM leading_causes', con=engine)
state_causes_group = state_causes.groupby(['cause_name'])
state_causes_df = state_causes_group['total_state_deaths'].sum()
state_causes_df.sort_values(ascending=False)
# Out:
# cause_name
# All Causes                                                               104679025
# Diseases of heart (I00-I09,I11,I13,I20-I51)                               24945550
# Malignant neoplasms (C00-C97)                                             23705490
# Chronic lower respiratory diseases (J40-J47)                               6059430
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)                       5744300
# Cerebrovascular diseases (I60-I69)                                         5445460
# Alzheimer's disease (G30)                                                  4049720
# Diabetes mellitus (E10-E14)                                                3116590
# Influenza and pneumonia (J09-J18)                                          2208050
# Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)      1952630
# Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                       1731330
# Name: total_state_deaths, dtype: int64

# %% [markdown]
# # Chronic Disease Indicators
#
# #### Column Descriptions:
# * YearStart - Starting Year
# * YearEnd - Ending Year
# * LocationAbbr - Location Abbreviation
# * LocationDesc - Location Description
# * DataSource - Data Source Abbreviation
# * Topic - Topic
# * Question - Question full-length text
# * Response - Response
# * DataValueUnit - The unit, such as $, %, years, etc.
# * DataValueType - The data type, such as prevalence or mean
# * DataValue - Data Value, such as 14.7 or Category 1
# * DataValueAlt - Equal to Data Value, but formatting is numeric
# * DataValueFootnoteSymbol	- Footnote Symbol
# * DatavalueFootnote - Footnote Text
# * LowConfidenceLimit - Low Confidence Limit
# * HighConfidenceLimit - High Confidence Limit
# * StratificationCategory1	- The category of the stratification, such as * Gender, Overall, or Race/Ethnicity
# * Stratification1	- The stratification within the category, such as Male or Female, White/non-Hispanic, Hispanic, Black/non-Hispanic, American Indian or Alaska Native, Asian or Pacific Islander, Multi-racial/non-Hispanic, Other/non-Hispanic, or Overall
# * StratificationCategory2
# * Stratification2
# * StratificationCategory3
# * Stratification3
# * GeoLocation	- Location code to be used for Geocoding
# * ResponseID - Identifier for the Response
# * LocationID - Location Identifier
# * TopicID
# * QuestionID - Question Identifier
# * DataValueTypeID	- Identifier for the Data Value Type
# * StratificationCategoryID1 - Identifier for stratification category 1
# * StratificationID1 - Identifier for stratification 1
# * StratificationCategoryID2
# * StratificationID2
# * StratificationCategoryID3
# * StratificationID3

# %%
# read chronic diseases indicators csv
CDI_df = pd.read_csv('Resources/U.S._Chronic_Disease_Indicators__CDI_.csv')
CDI_df.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (7,10,18,19,20,21,23,30,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0       2016     2016           US  United States      BRFSS  Alcohol
# 1       2016     2016           AL        Alabama      BRFSS  Alcohol
# 2       2016     2016           AK         Alaska      BRFSS  Alcohol
# 3       2016     2016           AZ        Arizona      BRFSS  Alcohol
# 4       2016     2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType  ... LocationID  TopicID QuestionID DataValueTypeID  \
# 0  Crude Prevalence  ...         59      ALC     ALC2_2         CRDPREV
# 1  Crude Prevalence  ...          1      ALC     ALC2_2         CRDPREV
# 2  Crude Prevalence  ...          2      ALC     ALC2_2         CRDPREV
# 3  Crude Prevalence  ...          4      ALC     ALC2_2         CRDPREV
# 4  Crude Prevalence  ...          5      ALC     ALC2_2         CRDPREV
#
#    StratificationCategoryID1  StratificationID1 StratificationCategoryID2  \
# 0                    OVERALL                OVR                       NaN
# 1                    OVERALL                OVR                       NaN
# 2                    OVERALL                OVR                       NaN
# 3                    OVERALL                OVR                       NaN
# 4                    OVERALL                OVR                       NaN
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0               NaN                       NaN               NaN
# 1               NaN                       NaN               NaN
# 2               NaN                       NaN               NaN
# 3               NaN                       NaN               NaN
# 4               NaN                       NaN               NaN
#
# [5 rows x 34 columns]

# %%
## CLEAN UP DATAFRAME
# Remove uncessary columns
CDI_df = CDI_df[['YearStart', 'LocationAbbr', 'LocationDesc', 'Topic', 'Question', 'DataValue', 'DataValueUnit', 'DataValueType', 'StratificationCategory1', 'Stratification1']]

CDI_df.head()
# Out:
#    YearStart LocationAbbr   LocationDesc    Topic  \
# 0       2016           US  United States  Alcohol
# 1       2016           AL        Alabama  Alcohol
# 2       2016           AK         Alaska  Alcohol
# 3       2016           AZ        Arizona  Alcohol
# 4       2016           AR       Arkansas  Alcohol
#
#                                             Question DataValue DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      16.9             %
# 1  Binge drinking prevalence among adults aged >=...        13             %
# 2  Binge drinking prevalence among adults aged >=...      18.2             %
# 3  Binge drinking prevalence among adults aged >=...      15.6             %
# 4  Binge drinking prevalence among adults aged >=...        15             %
#
#       DataValueType StratificationCategory1 Stratification1
# 0  Crude Prevalence                 Overall         Overall
# 1  Crude Prevalence                 Overall         Overall
# 2  Crude Prevalence                 Overall         Overall
# 3  Crude Prevalence                 Overall         Overall
# 4  Crude Prevalence                 Overall         Overall

# %%
CDI_topic_df = CDI_df[['Topic']]
CDI_topic_df
# Out:
#                          Topic
# 0                      Alcohol
# 1                      Alcohol
# 2                      Alcohol
# 3                      Alcohol
# 4                      Alcohol
# 5                      Alcohol
# 6                      Alcohol
# 7                      Alcohol
# 8                      Alcohol
# 9                      Alcohol
# 10                     Alcohol
# 11                     Alcohol
# 12                     Alcohol
# 13                     Alcohol
# 14                     Alcohol
# 15                     Alcohol
# 16                     Alcohol
# 17                     Alcohol
# 18                     Alcohol
# 19                     Alcohol
# 20                     Alcohol
# 21                     Alcohol
# 22                     Alcohol
# 23                     Alcohol
# 24                     Alcohol
# 25                     Alcohol
# 26                     Alcohol
# 27                     Alcohol
# 28                     Alcohol
# 29                     Alcohol
# ...                        ...
# 519688             Oral Health
# 519689             Oral Health
# 519690             Oral Health
# 519691             Oral Health
# 519692             Oral Health
# 519693             Oral Health
# 519694             Oral Health
# 519695             Oral Health
# 519696             Oral Health
# 519697             Oral Health
# 519698             Oral Health
# 519699  Overarching Conditions
# 519700  Overarching Conditions
# 519701  Overarching Conditions
# 519702  Overarching Conditions
# 519703  Overarching Conditions
# 519704  Overarching Conditions
# 519705  Overarching Conditions
# 519706  Overarching Conditions
# 519707  Overarching Conditions
# 519708  Overarching Conditions
# 519709                 Tobacco
# 519710                 Tobacco
# 519711                 Tobacco
# 519712                 Tobacco
# 519713                 Tobacco
# 519714                 Tobacco
# 519715                 Tobacco
# 519716                 Tobacco
# 519717              Disability
#
# [519718 rows x 1 columns]

# %%
# Obtain rows only for the all of the United States
CDI_US = CDI_df.loc[CDI_df['LocationAbbr']=="US",:]

# Obtain rows only for the years >=2013
CDI_US = CDI_US.loc[CDI_US['YearStart']>=2013, :]
CDI_US
# Out:
#         YearStart LocationAbbr   LocationDesc                   Topic  \
# 0            2016           US  United States                 Alcohol
# 55           2016           US  United States                 Alcohol
# 110          2016           US  United States                 Alcohol
# 165          2016           US  United States                 Alcohol
# 220          2016           US  United States                 Alcohol
# 275          2016           US  United States                 Alcohol
# 874          2016           US  United States                 Alcohol
# 1201         2016           US  United States                 Alcohol
# 1254         2016           US  United States                 Alcohol
# 1310         2016           US  United States                 Alcohol
# 1365         2016           US  United States                 Alcohol
# 1420         2016           US  United States                 Alcohol
# 1475         2016           US  United States                 Alcohol
# 1935         2016           US  United States                 Alcohol
# 2125         2016           US  United States                 Alcohol
# 2180         2016           US  United States                 Alcohol
# 2235         2016           US  United States                 Alcohol
# 2290         2016           US  United States                 Alcohol
# 2345         2016           US  United States                 Alcohol
# 2943         2016           US  United States                 Alcohol
# 2990         2016           US  United States                 Alcohol
# 3045         2016           US  United States                 Alcohol
# 3100         2016           US  United States                 Alcohol
# 3155         2016           US  United States                 Alcohol
# 3210         2016           US  United States                 Alcohol
# 3806         2016           US  United States                 Alcohol
# 4134         2016           US  United States               Arthritis
# 4185         2016           US  United States               Arthritis
# 4240         2016           US  United States               Arthritis
# 4295         2016           US  United States               Arthritis
# ...           ...          ...            ...                     ...
# 519020       2013           US  United States  Cardiovascular Disease
# 519021       2013           US  United States  Cardiovascular Disease
# 519025       2014           US  United States                Diabetes
# 519026       2014           US  United States                Diabetes
# 519027       2016           US  United States                Diabetes
# 519028       2016           US  United States                Diabetes
# 519046       2014           US  United States                Diabetes
# 519047       2014           US  United States                Diabetes
# 519048       2014           US  United States                Diabetes
# 519049       2013           US  United States                Diabetes
# 519050       2013           US  United States                Diabetes
# 519051       2013           US  United States                Diabetes
# 519055       2014           US  United States                Diabetes
# 519056       2014           US  United States                Diabetes
# 519057       2016           US  United States                Diabetes
# 519058       2016           US  United States                Diabetes
# 519059       2016           US  United States                Diabetes
# 519060       2016           US  United States                Diabetes
# 519061       2014           US  United States                Diabetes
# 519062       2014           US  United States                Diabetes
# 519063       2014           US  United States                Diabetes
# 519064       2014           US  United States                Diabetes
# 519065       2016           US  United States                Diabetes
# 519066       2016           US  United States                Diabetes
# 519085       2014           US  United States                Diabetes
# 519086       2014           US  United States                Diabetes
# 519087       2014           US  United States                Diabetes
# 519088       2013           US  United States                Diabetes
# 519089       2013           US  United States                Diabetes
# 519090       2013           US  United States                Diabetes
#
#                                                  Question DataValue  \
# 0       Binge drinking prevalence among adults aged >=...      16.9
# 55      Binge drinking prevalence among adults aged >=...      17.9
# 110     Binge drinking prevalence among adults aged >=...      21.9
# 165     Binge drinking prevalence among adults aged >=...      22.5
# 220     Binge drinking prevalence among adults aged >=...        12
# 275     Binge drinking prevalence among adults aged >=...      13.1
# 874     Binge drinking prevalence among women aged 18-...      18.7
# 1201    Binge drinking frequency among adults aged >= ...       4.6
# 1254    Binge drinking frequency among adults aged >= ...       4.7
# 1310    Binge drinking frequency among adults aged >= ...         5
# 1365    Binge drinking frequency among adults aged >= ...         5
# 1420    Binge drinking frequency among adults aged >= ...       3.5
# 1475    Binge drinking frequency among adults aged >= ...       3.6
# 1935    Binge drinking intensity among adults aged >= ...       7.4
# 2125    Binge drinking intensity among adults aged >= ...       7.1
# 2180    Binge drinking intensity among adults aged >= ...       8.5
# 2235    Binge drinking intensity among adults aged >= ...       8.2
# 2290    Binge drinking intensity among adults aged >= ...       5.6
# 2345    Binge drinking intensity among adults aged >= ...       5.3
# 2943         Heavy drinking among adults aged >= 18 years       6.5
# 2990         Heavy drinking among adults aged >= 18 years       6.7
# 3045         Heavy drinking among adults aged >= 18 years       7.1
# 3100         Heavy drinking among adults aged >= 18 years       7.2
# 3155         Heavy drinking among adults aged >= 18 years       5.9
# 3210         Heavy drinking among adults aged >= 18 years         6
# 3806          Heavy drinking among women aged 18-44 years       6.6
# 4134              Arthritis among adults aged >= 18 years      25.8
# 4185              Arthritis among adults aged >= 18 years      23.9
# 4240              Arthritis among adults aged >= 18 years      22.1
# 4295              Arthritis among adults aged >= 18 years      20.9
# ...                                                   ...       ...
# 519020    Hospitalization for acute myocardial infarction       NaN
# 519021    Hospitalization for acute myocardial infarction       NaN
# 519025  Adults with diagnosed diabetes aged >= 18 year...       NaN
# 519026  Adults with diagnosed diabetes aged >= 18 year...       NaN
# 519027  Adults with diagnosed diabetes aged >= 18 year...       NaN
# 519028  Adults with diagnosed diabetes aged >= 18 year...       NaN
# 519046  Amputation of a lower extremity attributable t...       NaN
# 519047  Amputation of a lower extremity attributable t...       NaN
# 519048  Amputation of a lower extremity attributable t...       NaN
# 519049  Amputation of a lower extremity attributable t...       NaN
# 519050  Amputation of a lower extremity attributable t...       NaN
# 519051  Amputation of a lower extremity attributable t...       NaN
# 519055  Foot examination among adults aged >= 18 years...       NaN
# 519056  Foot examination among adults aged >= 18 years...       NaN
# 519057  Foot examination among adults aged >= 18 years...       NaN
# 519058  Foot examination among adults aged >= 18 years...       NaN
# 519059  Glycosylated hemoglobin measurement among adul...       NaN
# 519060  Glycosylated hemoglobin measurement among adul...       NaN
# 519061  Glycosylated hemoglobin measurement among adul...       NaN
# 519062  Glycosylated hemoglobin measurement among adul...       NaN
# 519063  Dilated eye examination among adults aged >= 1...       NaN
# 519064  Dilated eye examination among adults aged >= 1...       NaN
# 519065  Dilated eye examination among adults aged >= 1...       NaN
# 519066  Dilated eye examination among adults aged >= 1...       NaN
# 519085  Hospitalization with diabetes as a listed diag...       NaN
# 519086  Hospitalization with diabetes as a listed diag...       NaN
# 519087  Hospitalization with diabetes as a listed diag...       NaN
# 519088  Hospitalization with diabetes as a listed diag...       NaN
# 519089  Hospitalization with diabetes as a listed diag...       NaN
# 519090  Hospitalization with diabetes as a listed diag...       NaN
#
#            DataValueUnit            DataValueType StratificationCategory1  \
# 0                      %         Crude Prevalence                 Overall
# 55                     %  Age-adjusted Prevalence                 Overall
# 110                    %         Crude Prevalence                  Gender
# 165                    %  Age-adjusted Prevalence                  Gender
# 220                    %         Crude Prevalence                  Gender
# 275                    %  Age-adjusted Prevalence                  Gender
# 874                    %         Crude Prevalence                 Overall
# 1201              Number                     Mean                 Overall
# 1254              Number        Age-adjusted Mean                 Overall
# 1310              Number                     Mean                  Gender
# 1365              Number        Age-adjusted Mean                  Gender
# 1420              Number                     Mean                  Gender
# 1475              Number        Age-adjusted Mean                  Gender
# 1935              Number                     Mean                 Overall
# 2125              Number        Age-adjusted Mean                 Overall
# 2180              Number                     Mean                  Gender
# 2235              Number        Age-adjusted Mean                  Gender
# 2290              Number                     Mean                  Gender
# 2345              Number        Age-adjusted Mean                  Gender
# 2943                   %         Crude Prevalence                 Overall
# 2990                   %  Age-adjusted Prevalence                 Overall
# 3045                   %         Crude Prevalence                  Gender
# 3100                   %  Age-adjusted Prevalence                  Gender
# 3155                   %         Crude Prevalence                  Gender
# 3210                   %  Age-adjusted Prevalence                  Gender
# 3806                   %         Crude Prevalence                 Overall
# 4134                   %         Crude Prevalence                 Overall
# 4185                   %  Age-adjusted Prevalence                 Overall
# 4240                   %         Crude Prevalence                  Gender
# 4295                   %  Age-adjusted Prevalence                  Gender
# ...                  ...                      ...                     ...
# 519020  cases per 10,000               Crude Rate                 Overall
# 519021  cases per 10,000        Age-adjusted Rate                 Overall
# 519025                 %  Age-adjusted Prevalence                 Overall
# 519026                 %         Crude Prevalence                 Overall
# 519027                 %  Age-adjusted Prevalence                 Overall
# 519028                 %         Crude Prevalence                 Overall
# 519046               NaN                   Number                 Overall
# 519047  cases per 10,000               Crude Rate                 Overall
# 519048  cases per 10,000        Age-adjusted Rate                 Overall
# 519049               NaN                   Number                 Overall
# 519050  cases per 10,000               Crude Rate                 Overall
# 519051  cases per 10,000        Age-adjusted Rate                 Overall
# 519055                 %  Age-adjusted Prevalence                 Overall
# 519056                 %         Crude Prevalence                 Overall
# 519057                 %  Age-adjusted Prevalence                 Overall
# 519058                 %         Crude Prevalence                 Overall
# 519059                 %         Crude Prevalence                 Overall
# 519060                 %  Age-adjusted Prevalence                 Overall
# 519061                 %         Crude Prevalence                 Overall
# 519062                 %  Age-adjusted Prevalence                 Overall
# 519063                 %  Age-adjusted Prevalence                 Overall
# 519064                 %         Crude Prevalence                 Overall
# 519065                 %  Age-adjusted Prevalence                 Overall
# 519066                 %         Crude Prevalence                 Overall
# 519085               NaN                   Number                 Overall
# 519086  cases per 10,000               Crude Rate                 Overall
# 519087  cases per 10,000        Age-adjusted Rate                 Overall
# 519088               NaN                   Number                 Overall
# 519089  cases per 10,000               Crude Rate                 Overall
# 519090  cases per 10,000        Age-adjusted Rate                 Overall
#
#        Stratification1
# 0              Overall
# 55             Overall
# 110               Male
# 165               Male
# 220             Female
# 275             Female
# 874            Overall
# 1201           Overall
# 1254           Overall
# 1310              Male
# 1365              Male
# 1420            Female
# 1475            Female
# 1935           Overall
# 2125           Overall
# 2180              Male
# 2235              Male
# 2290            Female
# 2345            Female
# 2943           Overall
# 2990           Overall
# 3045              Male
# 3100              Male
# 3155            Female
# 3210            Female
# 3806           Overall
# 4134           Overall
# 4185           Overall
# 4240              Male
# 4295              Male
# ...                ...
# 519020         Overall
# 519021         Overall
# 519025         Overall
# 519026         Overall
# 519027         Overall
# 519028         Overall
# 519046         Overall
# 519047         Overall
# 519048         Overall
# 519049         Overall
# 519050         Overall
# 519051         Overall
# 519055         Overall
# 519056         Overall
# 519057         Overall
# 519058         Overall
# 519059         Overall
# 519060         Overall
# 519061         Overall
# 519062         Overall
# 519063         Overall
# 519064         Overall
# 519065         Overall
# 519066         Overall
# 519085         Overall
# 519086         Overall
# 519087         Overall
# 519088         Overall
# 519089         Overall
# 519090         Overall
#
# [2205 rows x 10 columns]

# %%
# Separate crude prevalence and age-adjusted prevalence into separate dataframes
CDI_US_crude = CDI_US.loc[CDI_US['DataValueType']=="Crude Prevalence",:]
CDI_US_age_adjusted = CDI_US.loc[CDI_US['DataValueType']=="Age-adjusted Prevalence", :]

# %%
CDI_US_crude.head()
# Out:
#       YearStart LocationAbbr   LocationDesc    Topic  \
# 0          2016           US  United States  Alcohol
# 110        2016           US  United States  Alcohol
# 220        2016           US  United States  Alcohol
# 874        2016           US  United States  Alcohol
# 2943       2016           US  United States  Alcohol
#
#                                                Question DataValue  \
# 0     Binge drinking prevalence among adults aged >=...      16.9
# 110   Binge drinking prevalence among adults aged >=...      21.9
# 220   Binge drinking prevalence among adults aged >=...        12
# 874   Binge drinking prevalence among women aged 18-...      18.7
# 2943       Heavy drinking among adults aged >= 18 years       6.5
#
#      DataValueUnit     DataValueType StratificationCategory1 Stratification1
# 0                %  Crude Prevalence                 Overall         Overall
# 110              %  Crude Prevalence                  Gender            Male
# 220              %  Crude Prevalence                  Gender          Female
# 874              %  Crude Prevalence                 Overall         Overall
# 2943             %  Crude Prevalence                 Overall         Overall

# %%
# Separate CDI_US_crude into 3 stratification categories: Overall, Gender Male, Gender Female

# Overall
CDI_US_crude_overall = CDI_US_crude.loc[CDI_US_crude['Stratification1']=="Overall",:]
# Male
CDI_US_crude_male = CDI_US_crude.loc[CDI_US_crude['Stratification1']=="Male",:]
# Female
CDI_US_crude_female = CDI_US_crude.loc[CDI_US_crude['Stratification1']=="Female",:]

# %%
CDI_US_crude_overall.head()

# %%
CDI_US_crude_male.head()

# %%
CDI_US_crude_female.head()

# %%
# Only Age adjusted datavaluetypes
CDI_US_age_adjusted.head()

# %%
# Separate CDI_US_crude into 3 stratification categories: Overall, Gender Male, Gender Female

# Overall
CDI_US_age_adjusted_overall = CDI_US_age_adjusted.loc[CDI_US_age_adjusted['Stratification1']=="Overall",:]
# Male
CDI_US_age_adjusted_male = CDI_US_age_adjusted.loc[CDI_US_age_adjusted['Stratification1']=="Male",:]
# Female
CDI_US_age_adjusted_female = CDI_US_age_adjusted.loc[CDI_US_age_adjusted['Stratification1']=="Female",:]

# %%
CDI_US_age_adjusted_overall.head()

# %%
CDI_US_age_adjusted_male.head()

# %%
CDI_US_age_adjusted_female.head()

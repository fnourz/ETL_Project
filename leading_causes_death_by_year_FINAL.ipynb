# %% [markdown]
# # ETL Project: Leading causes of death in the United States
#
# #### Aim:
# An analysis on the top 10 leading causes of death in the United States. This case study seeks to analyze the top causes of deaths from 2013 to 2016 by ranking death causes by year, state, and age-adjusted deaths. Further, would U.S. chronic disease indicators provide any insight into risk factors that may be associated with those leading causes of death?
#
# #### Notes:
# * The 10 leading causes of death are classified by the International Classification of Diseases, Tenth Revision (ICD-10).
# * Age-adjusted death rates are per 100,000 standard million population in the year 2000.
#
#
# #### Data sources:
# * [CDC/HCHS](https://catalog.data.gov/dataset/age-adjusted-death-rates-for-the-top-10-leading-causes-of-death-united-states-2013)
#
# * [CDC](https://catalog.data.gov/dataset/u-s-chronic-disease-indicators-cdi)
#
# #### Tools:
# * Jupter Notebook/Python 3
# * MySQL

# %% [markdown]
# # Leading Causes Of Death In The United States
# ## Data Extraction
#
# After downloading csv files from our sources, csv files were extracted into dataframes utilizing jupyter notebook python 3 pandas function pd.read_csv().

# %%
# import dependencies
import pandas as pd
import pymysql
from sqlalchemy import create_engine
engine = create_engine("mysql://root:Codingislife92!@localhost:3306/leading_causes_of_death_db")

# %%
# read csv file for data on leading causes of death
leading_causes_death_df = pd.read_csv('Resources/NCHS_-_Leading_Causes_of_Death__United_States.csv')

# %%
# preview the dataframe created
leading_causes_death_df.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %% [markdown]
# ## Data Transformation
# Due to the specificity contained in the column '113 Cause Name' in the leading_causes_death dataframe, it was decided that broader categories of death causes should be used to more closely match the Chronic Disease Indicators' categories for easier grouping of the two datasets. Thus utilizing the column 'Cause Name' as our main category.
#
# The column 'Age-adjusted Death Rate' was removed due to the lack of clarity from the datasource and not being able to to rank leading causes of death in a meaningful way. Columns were also renamed for easier analysis through python 3.

# %%
## cleaning the dataframe

# Remove cause_name and state columns, Rename columns into a new dataframe
leading_causes = leading_causes_death_df[['Year', 'Cause Name', 'State','Deaths']].copy()
leading_causes = leading_causes.rename(columns={
    "Year":"year",
    "Cause Name": "cause_name",
    "State": "state",
    "Deaths": "deaths"
})
leading_causes.sort_values(by=["year"]).head()
# Out:
#        year              cause_name          state  deaths
# 10295  1999  Unintentional injuries        Wyoming     258
# 1418   1999     Alzheimer's disease      Minnesota    1083
# 8726   1999                 Suicide       Illinois    1020
# 7016   1999          Kidney disease       Michigan    1417
# 4334   1999                Diabetes  New Hampshire     294

# %% [markdown]
# Since the data sets end in 2016, we chose the time frame from 2013 to 2016. This three year period was to sample for any possible relationships between leading causes of death and chronic disease indicators.

# %%
# Filter leading_causes for years >=2013
leading_causes_2013_to_2016 = leading_causes.loc[leading_causes['year'] >= 2013,:]
leading_causes_2013_to_2016=leading_causes_2013_to_2016.sort_values(by=['year'])
leading_causes_2013_to_2016.head()
# Out:
#        year              cause_name          state  deaths
# 10281  2013  Unintentional injuries        Wyoming     325
# 3708   2013                    CLRD       Virginia    3181
# 3726   2013                    CLRD     Washington    2933
# 8946   2013                 Suicide        Montana     243
# 3744   2013                    CLRD  West Virginia    1590

# %% [markdown]
# One of the categories in "cause_name" is "All causes". Since this is a summation of all the categories in "cause_name", it was decided that the "All causes" category should be removed from the dataset.

# %% [markdown]
# ### Death analysis in US

# %% [markdown]
# Since the data set merged both all of the United States and individual states, we separated the two areas to take into account of the leading causes of death in the United States and in each individual state by year.

# %%
# Remove all causes from dataframe
leading_causes_2013_to_2016_individual = leading_causes_2013_to_2016[leading_causes_2013_to_2016.cause_name != "All causes"]
leading_causes_2013_to_2016_individual.head()
# Out:
#        year              cause_name          state  deaths
# 10281  2013  Unintentional injuries        Wyoming     325
# 3708   2013                    CLRD       Virginia    3181
# 3726   2013                    CLRD     Washington    2933
# 8946   2013                 Suicide        Montana     243
# 3744   2013                    CLRD  West Virginia    1590

# %% [markdown]
# After dropping “all causes” we aimed to see the top ten causes for death in the entire United States. Since the dataset has leading cause of death values for all states as well as the entire United States, we are looking at the leading causes of death for the United States and then for the states individually. For example, the state of California’s top 10 leading causes of death may be different than the entire United States’top 10 leading causes of death. Therefor we have to observe the states separately from the United States. Below are the results for the top 10 leading causes of deaths in the United States for the years 2013-2016.

# %%
# Separate US from individual states (2013 to 2016)
leading_causes_2013_to_2016_individual_US = leading_causes_2013_to_2016_individual[leading_causes_2013_to_2016_individual.state == "United States"]
leading_causes_2013_to_2016_individual_US.head()

#leading cause of death in the United States for 2013
leading_causes_2013_individual_US = leading_causes_2013_to_2016_individual_US.loc[leading_causes_2013_to_2016_individual_US['year']==2013,:]
leading_causes_2013_individual_US.sort_values(by=['deaths'], ascending=False).head(10)
# Out:
#        year               cause_name          state  deaths
# 5528   2013            Heart disease  United States  611105
# 2718   2013                   Cancer  United States  584881
# 3654   2013                     CLRD  United States  149205
# 10162  2013   Unintentional injuries  United States  130557
# 8334   2013                   Stroke  United States  128978
# 1782   2013      Alzheimer's disease  United States   84767
# 4590   2013                 Diabetes  United States   75578
# 6462   2013  Influenza and pneumonia  United States   56979
# 7399   2013           Kidney disease  United States   47112
# 9270   2013                  Suicide  United States   41149

# %%
#leading cause of death in the United States for 2014
leading_causes_2014_individual_US = leading_causes_2013_to_2016_individual_US.loc[leading_causes_2013_to_2016_individual_US['year']==2014,:]
leading_causes_2014_individual_US.sort_values(by=['deaths'], ascending=False).head(10)
# Out:
#        year               cause_name          state  deaths
# 5527   2014            Heart disease  United States  614348
# 2717   2014                   Cancer  United States  591700
# 3653   2014                     CLRD  United States  147101
# 10161  2014   Unintentional injuries  United States  135928
# 8333   2014                   Stroke  United States  133103
# 1781   2014      Alzheimer's disease  United States   93541
# 4589   2014                 Diabetes  United States   76488
# 6461   2014  Influenza and pneumonia  United States   55227
# 7398   2014           Kidney disease  United States   48146
# 9269   2014                  Suicide  United States   42826

# %%
#leading cause of death in the United States for 2015
leading_causes_2015_individual_US = leading_causes_2013_to_2016_individual_US.loc[leading_causes_2013_to_2016_individual_US['year']==2015,:]
leading_causes_2015_individual_US.sort_values(by=['deaths'], ascending=False).head(10)
# Out:
#        year               cause_name          state  deaths
# 5526   2015            Heart disease  United States  633842
# 2716   2015                   Cancer  United States  595930
# 3652   2015                     CLRD  United States  155041
# 10160  2015   Unintentional injuries  United States  146571
# 8332   2015                   Stroke  United States  140323
# 1780   2015      Alzheimer's disease  United States  110561
# 4588   2015                 Diabetes  United States   79535
# 6460   2015  Influenza and pneumonia  United States   57062
# 7397   2015           Kidney disease  United States   49959
# 9268   2015                  Suicide  United States   44193

# %%
#leading cause of death in the United States for 2016
leading_causes_2016_individual_US = leading_causes_2013_to_2016_individual_US.loc[leading_causes_2013_to_2016_individual_US['year']==2016,:]
leading_causes_2016_individual_US.sort_values(by=['deaths'], ascending=False).head(10)
# Out:
#        year               cause_name          state  deaths
# 5525   2016            Heart disease  United States  635260
# 2715   2016                   Cancer  United States  598038
# 10159  2016   Unintentional injuries  United States  161374
# 3651   2016                     CLRD  United States  154596
# 8331   2016                   Stroke  United States  142142
# 1779   2016      Alzheimer's disease  United States  116103
# 4587   2016                 Diabetes  United States   80058
# 6459   2016  Influenza and pneumonia  United States   51537
# 7396   2016           Kidney disease  United States   50046
# 9267   2016                  Suicide  United States   44965

# %%
# ALL US 2013 Top 10 leading deaths
# Isolate only 2013 data
top_10_leading_2013_US = leading_causes_2013_to_2016_individual_US.loc[leading_causes_2013_to_2016_individual_US['year']==2013,:]
top_10_leading_2013_US = top_10_leading_2013_US.sort_values(by=['deaths'], ascending=False).head(10)
top_10_leading_2013_US
# Out:
#        year               cause_name          state  deaths
# 5528   2013            Heart disease  United States  611105
# 2718   2013                   Cancer  United States  584881
# 3654   2013                     CLRD  United States  149205
# 10162  2013   Unintentional injuries  United States  130557
# 8334   2013                   Stroke  United States  128978
# 1782   2013      Alzheimer's disease  United States   84767
# 4590   2013                 Diabetes  United States   75578
# 6462   2013  Influenza and pneumonia  United States   56979
# 7399   2013           Kidney disease  United States   47112
# 9270   2013                  Suicide  United States   41149

# %%
# ALL US 2014 Top 10 leading deaths
# Isolate only 2014 data
top_10_leading_2014_US = leading_causes_2013_to_2016_individual_US.loc[leading_causes_2013_to_2016_individual_US['year']==2014,:]
top_10_leading_2014_US = top_10_leading_2014_US.sort_values(by=['deaths'], ascending=False).head(10)
top_10_leading_2014_US
# Out:
#        year               cause_name          state  deaths
# 5527   2014            Heart disease  United States  614348
# 2717   2014                   Cancer  United States  591700
# 3653   2014                     CLRD  United States  147101
# 10161  2014   Unintentional injuries  United States  135928
# 8333   2014                   Stroke  United States  133103
# 1781   2014      Alzheimer's disease  United States   93541
# 4589   2014                 Diabetes  United States   76488
# 6461   2014  Influenza and pneumonia  United States   55227
# 7398   2014           Kidney disease  United States   48146
# 9269   2014                  Suicide  United States   42826

# %%
# ALL US 2015 Top 10 leading deaths
# Isolate only 2015 data
top_10_leading_2015_US = leading_causes_2013_to_2016_individual_US.loc[leading_causes_2013_to_2016_individual_US['year']==2015,:]
top_10_leading_2015_US = top_10_leading_2015_US.sort_values(by=['deaths'], ascending=False).head(10)
top_10_leading_2015_US
# Out:
#        year               cause_name          state  deaths
# 5526   2015            Heart disease  United States  633842
# 2716   2015                   Cancer  United States  595930
# 3652   2015                     CLRD  United States  155041
# 10160  2015   Unintentional injuries  United States  146571
# 8332   2015                   Stroke  United States  140323
# 1780   2015      Alzheimer's disease  United States  110561
# 4588   2015                 Diabetes  United States   79535
# 6460   2015  Influenza and pneumonia  United States   57062
# 7397   2015           Kidney disease  United States   49959
# 9268   2015                  Suicide  United States   44193

# %% [markdown]
# ### Death analysis per state

# %% [markdown]
# ### As per above report top 10 states having more death count are [California, Florida, Texas, New York, Pennsylvania, Ohio, Illinois, Michigan, North Carolina, Georgia]

# %%
#engine = create_engine("mysql://root:Codingislife92!@localhost:3306/leading_causes_of_death_db")
pymysql.install_as_MySQLdb()
leading_causes_2013_to_2016.to_sql(name='leading_causes', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('SELECT * FROM leading_causes', con=engine).head()
# Out:
#    year              cause_name          state  deaths
# 0  2013  Unintentional injuries        Wyoming     325
# 1  2013                    CLRD       Virginia    3181
# 2  2013                    CLRD     Washington    2933
# 3  2013                 Suicide        Montana     243
# 4  2013                    CLRD  West Virginia    1590

# %%
# Deaths per state
state_deaths = pd.read_sql_query('SELECT state as State, deaths as total_state_deaths \
                FROM leading_causes', con=engine)
# Group by state
deaths_state = state_deaths.groupby(['State'])
# count total number of deaths per state
deaths_state_df = deaths_state['total_state_deaths'].sum()
deaths_per_state = deaths_state_df.sort_values(ascending=False)
deaths_per_state
# Out:
# State
# United States           36302742
# California               3594654
# Florida                  2641190
# Texas                    2567016
# New York                 2134936
# Pennsylvania             1812200
# Ohio                     1620386
# Illinois                 1470064
# Michigan                 1329726
# North Carolina           1203290
# Georgia                  1081434
# New Jersey                995432
# Tennessee                 918922
# Virginia                  888782
# Indiana                   858830
# Missouri                  830076
# Massachusetts             761876
# Arizona                   741792
# Washington                740866
# Alabama                   710528
# Wisconsin                 707046
# Maryland                  640944
# South Carolina            640628
# Kentucky                  639390
# Louisiana                 611966
# Minnesota                 572790
# Oklahoma                  551108
# Colorado                  493130
# Oregon                    477310
# Mississippi               439700
# Arkansas                  438622
# Connecticut               412134
# Iowa                      409464
# Kansas                    357486
# Nevada                    319624
# West Virginia             310600
# New Mexico                241732
# Utah                      232932
# Nebraska                  221032
# Maine                     192386
# Idaho                     177990
# New Hampshire             161290
# Hawaii                    150384
# Rhode Island              136410
# Montana                   133466
# Delaware                  117380
# South Dakota              106582
# North Dakota               86474
# Vermont                    80538
# District of Columbia       66508
# Wyoming                    64942
# Alaska                     58300
# Name: total_state_deaths, dtype: int64

# %%
# Adding selected columns to mysql
state_deaths.to_sql(name='state_deaths', con=engine, if_exists='append', index=False)

# %%
# Deaths in each state per cause per year
state_cause_deaths = pd.read_sql_query('SELECT state, cause_name, year, deaths as total_state_deaths \
                FROM leading_causes', con=engine)
# Groupby statem, cause name, year
deaths_state = state_cause_deaths.groupby(['state', 'cause_name', 'year'])
# count total deaths
deaths_state_df = deaths_state['total_state_deaths'].sum()
deaths_state_df = deaths_state_df.sort_values
print(deaths_state_df)
# Out:
# <bound method Series.sort_values of state    cause_name               year
# Alabama  All causes               2013    100378
#                                   2014    100430
#                                   2015    103818
#                                   2016    104932
#          Alzheimer's disease      2013      2796
#                                   2014      3770
#                                   2015      4564
#                                   2016      5014
#          CLRD                     2013      6086
#                                   2014      6100
#                                   2015      6558
#                                   2016      6652
#          Cancer                   2013     20656
#                                   2014     20572
#                                   2015     20708
#                                   2016     20838
#          Diabetes                 2013      2698
#                                   2014      2562
#                                   2015      2510
#                                   2016      2366
#          Heart disease            2013     24944
#                                   2014     24922
#                                   2015     25962
#                                   2016     25664
#          Influenza and pneumonia  2013      2070
#                                   2014      2062
#                                   2015      2194
#                                   2016      1974
#          Kidney disease           2013      2114
#                                   2014      2022
#                                            ...
# Wyoming  Cancer                   2015      1862
#                                   2016      1924
#          Diabetes                 2013       178
#                                   2014       220
#                                   2015       272
#                                   2016       224
#          Heart disease            2013      1878
#                                   2014      2070
#                                   2015      2060
#                                   2016      2102
#          Influenza and pneumonia  2013       224
#                                   2014       226
#                                   2015       198
#                                   2016       198
#          Kidney disease           2013       112
#                                   2014       156
#                                   2015       172
#                                   2016       132
#          Stroke                   2013       426
#                                   2014       378
#                                   2015       396
#                                   2016       416
#          Suicide                  2013       258
#                                   2014       240
#                                   2015       314
#                                   2016       288
#          Unintentional injuries   2013       650
#                                   2014       722
#                                   2015       800
#                                   2016       742
# Name: total_state_deaths, Length: 2288, dtype: int64>

# %%
# Adding selected data to mysql
state_cause_deaths.to_sql(name='state_cause_deaths', con=engine, if_exists='append', index=False)

# %%
# Deaths per cause
death_causes = pd.read_sql_query('SELECT cause_name, deaths as total_state_deaths \
                FROM leading_causes', con=engine)
# Group by cause name
state_causes_group = death_causes.groupby(['cause_name'])
# count total number of deaths per cause
state_causes_df = state_causes_group['total_state_deaths'].sum()
state_causes_df.sort_values(ascending=False)
# Out:
# cause_name
# All causes                 41871610
# Heart disease               9978220
# Cancer                      9482196
# CLRD                        2423772
# Unintentional injuries      2297720
# Stroke                      2178184
# Alzheimer's disease         1619888
# Diabetes                    1246636
# Influenza and pneumonia      883220
# Kidney disease               781052
# Suicide                      692532
# Name: total_state_deaths, dtype: int64

# %% [markdown]
# ### As per above analysis, top causes of death are Heart disease, followed by Malignant neoplasms and then cancer.

# %%
death_causes.to_sql(name='death_causes', con=engine, if_exists='append', index=False)

# %%
# Separate out states from 2013 to 2016
leading_causes_2013_to_2016_individual_states = leading_causes_2013_to_2016_individual[leading_causes_2013_to_2016_individual.state != "United States"]
leading_causes_2013_to_2016_individual_states.head()
# Out:
#        year              cause_name          state  deaths
# 10281  2013  Unintentional injuries        Wyoming     325
# 3708   2013                    CLRD       Virginia    3181
# 3726   2013                    CLRD     Washington    2933
# 8946   2013                 Suicide        Montana     243
# 3744   2013                    CLRD  West Virginia    1590

# %%
# ALL STATES 2013 Top 10 leading deaths and which states had the most deaths in the year 2013
# Isolate only 2013 data
leading_2013_states = leading_causes_2013_to_2016_individual_states.loc[leading_causes_2013_to_2016_individual_states['year']==2013,:]
top_10_leading_2013_states_all = leading_2013_states.sort_values(by=['deaths'], ascending=False).head(10)
top_10_leading_2013_states_all
# Out:
#       year     cause_name         state  deaths
# 4806  2013  Heart disease    California   60299
# 1998  2013         Cancer    California   57714
# 5311  2013  Heart disease      New York   44039
# 2088  2013         Cancer       Florida   42735
# 4896  2013  Heart disease       Florida   42656
# 5510  2013  Heart disease         Texas   40203
# 2700  2013         Cancer         Texas   38412
# 2502  2013         Cancer      New York   35738
# 5419  2013  Heart disease  Pennsylvania   31629
# 2610  2013         Cancer  Pennsylvania   28512

# %%
# Top 10 unique states 2013
# Sort data by number of death from highest to lowest, drop any duplicate states for this year, and obtain only the top 10 states
top_10_leading_2013_states_unique = leading_2013_states.sort_values(by=['deaths'], ascending=False).drop_duplicates(subset='state', keep='first').head(10)
top_10_leading_2013_states_unique
# Out:
#       year     cause_name           state  deaths
# 4806  2013  Heart disease      California   60299
# 5311  2013  Heart disease        New York   44039
# 2088  2013         Cancer         Florida   42735
# 5510  2013  Heart disease           Texas   40203
# 5419  2013  Heart disease    Pennsylvania   31629
# 5365  2013  Heart disease            Ohio   26878
# 4968  2013  Heart disease        Illinois   24839
# 5131  2013  Heart disease        Michigan   24156
# 2520  2013         Cancer  North Carolina   18589
# 5275  2013  Heart disease      New Jersey   18460

# %%
# ALL STATES 2014 Top 10 leading deaths and which states had the most deaths in the year 2014
# Isolate only 2014 data
leading_2014_states = leading_causes_2013_to_2016_individual_states.loc[leading_causes_2013_to_2016_individual_states['year']==2014,:]
top_10_leading_2014_states_all = leading_2014_states.sort_values(by=['deaths'], ascending=False).head(10)
top_10_leading_2014_states_all
# Out:
#       year     cause_name         state  deaths
# 1997  2014         Cancer    California   58412
# 4805  2014  Heart disease    California   58189
# 4895  2014  Heart disease       Florida   44511
# 2087  2014         Cancer       Florida   43212
# 5310  2014  Heart disease      New York   43116
# 5509  2014  Heart disease         Texas   41479
# 2699  2014         Cancer         Texas   38847
# 2501  2014         Cancer      New York   35392
# 5418  2014  Heart disease  Pennsylvania   31353
# 2609  2014         Cancer  Pennsylvania   28692

# %%
# Top 10 unique states 2014
# Sort data by number of death from highest to lowest, drop any duplicate states for this year, and obtain only the top 10 states
top_10_leading_2014_states_unique = leading_2014_states.sort_values(by=['deaths'], ascending=False).drop_duplicates(subset='state', keep='first').head(10)
top_10_leading_2014_states_unique
# Out:
#       year     cause_name           state  deaths
# 1997  2014         Cancer      California   58412
# 4895  2014  Heart disease         Florida   44511
# 5310  2014  Heart disease        New York   43116
# 5509  2014  Heart disease           Texas   41479
# 5418  2014  Heart disease    Pennsylvania   31353
# 5364  2014  Heart disease            Ohio   27000
# 4967  2014  Heart disease        Illinois   25024
# 5130  2014  Heart disease        Michigan   24692
# 2519  2014         Cancer  North Carolina   19342
# 5274  2014  Heart disease      New Jersey   18319

# %%
# ALL STATES 2015 Top 10 leading deaths and which states had the most deaths in the year 2015
# Isolate only 2015 data
leading_2015_states = leading_causes_2013_to_2016_individual_states.loc[leading_causes_2013_to_2016_individual_states['year']==2015,:]
top_10_leading_2015_states_all = leading_2015_states.sort_values(by=['deaths'], ascending=False).head(10)
top_10_leading_2015_states_all
# Out:
#       year     cause_name         state  deaths
# 4804  2015  Heart disease    California   61289
# 1996  2015         Cancer    California   59629
# 4894  2015  Heart disease       Florida   45441
# 5309  2015  Heart disease      New York   44450
# 2086  2015         Cancer       Florida   44027
# 5508  2015  Heart disease         Texas   43298
# 2698  2015         Cancer         Texas   39121
# 2500  2015         Cancer      New York   35089
# 5417  2015  Heart disease  Pennsylvania   32042
# 2608  2015         Cancer  Pennsylvania   28697

# %%
# Top 10 unique states 2015
# Sort data by number of death from highest to lowest, drop any duplicate states for this year, and obtain only the top 10 states
top_10_leading_2015_states_unique = leading_2015_states.sort_values(by=['deaths'], ascending=False).drop_duplicates(subset='state', keep='first').head(10)
top_10_leading_2015_states_unique
# Out:
#       year     cause_name           state  deaths
# 4804  2015  Heart disease      California   61289
# 4894  2015  Heart disease         Florida   45441
# 5309  2015  Heart disease        New York   44450
# 5508  2015  Heart disease           Texas   43298
# 5417  2015  Heart disease    Pennsylvania   32042
# 5363  2015  Heart disease            Ohio   28069
# 4966  2015  Heart disease        Illinois   25652
# 5129  2015  Heart disease        Michigan   24794
# 2518  2015         Cancer  North Carolina   19322
# 5273  2015  Heart disease      New Jersey   18647

# %%
# ALL STATES 2016 Top 10 leading deaths and which states had the most deaths in the year 2016
# Isolate only 2016 data
leading_2016_states = leading_causes_2013_to_2016_individual_states.loc[leading_causes_2013_to_2016_individual_states['year']==2016,:]
top_10_leading_2016_states_all = leading_2016_states.sort_values(by=['deaths'], ascending=False).head(10)
top_10_leading_2016_states_all
# Out:
#       year     cause_name         state  deaths
# 4803  2016  Heart disease    California   61573
# 1995  2016         Cancer    California   59515
# 4893  2016  Heart disease       Florida   45659
# 2085  2016         Cancer       Florida   44266
# 5308  2016  Heart disease      New York   44076
# 5506  2016  Heart disease         Texas   43772
# 2697  2016         Cancer         Texas   40195
# 2499  2016         Cancer      New York   35368
# 5416  2016  Heart disease  Pennsylvania   31990
# 2607  2016         Cancer  Pennsylvania   28492

# %%
# Top 10 unique states 2016
# Sort data by number of death from highest to lowest, drop any duplicate states for this year, and obtain only the top 10 states
top_10_leading_2016_states_unique = leading_2016_states.sort_values(by=['deaths'], ascending=False).drop_duplicates(subset='state', keep='first').head(10)
top_10_leading_2016_states_unique
# Out:
#       year     cause_name           state  deaths
# 4803  2016  Heart disease      California   61573
# 4893  2016  Heart disease         Florida   45659
# 5308  2016  Heart disease        New York   44076
# 5506  2016  Heart disease           Texas   43772
# 5416  2016  Heart disease    Pennsylvania   31990
# 5362  2016  Heart disease            Ohio   27410
# 5128  2016  Heart disease        Michigan   25304
# 4965  2016  Heart disease        Illinois   25013
# 2517  2016         Cancer  North Carolina   19523
# 5272  2016  Heart disease      New Jersey   18597

# %% [markdown]
# # Chronic Disease Indicators
#
# #### Column Descriptions:
# * YearStart - Starting Year
# * YearEnd - Ending Year
# * LocationAbbr - Location Abbreviation
# * LocationDesc - Location Description
# * DataSource - Data Source Abbreviation
# * Topic - Topic
# * Question - Question full-length text
# * Response - Response
# * DataValueUnit - The unit, such as $, %, years, etc.
# * DataValueType - The data type, such as prevalence or mean
# * DataValue - Data Value, such as 14.7 or Category 1
# * DataValueAlt - Equal to Data Value, but formatting is numeric
# * DataValueFootnoteSymbol	- Footnote Symbol
# * DatavalueFootnote - Footnote Text
# * LowConfidenceLimit - Low Confidence Limit
# * HighConfidenceLimit - High Confidence Limit
# * StratificationCategory1	- The category of the stratification, such as * Gender, Overall, or Race/Ethnicity
# * Stratification1	- The stratification within the category, such as Male or Female, White/non-Hispanic, Hispanic, Black/non-Hispanic, American Indian or Alaska Native, Asian or Pacific Islander, Multi-racial/non-Hispanic, Other/non-Hispanic, or Overall
# * StratificationCategory2
# * Stratification2
# * StratificationCategory3
# * Stratification3
# * GeoLocation	- Location code to be used for Geocoding
# * ResponseID - Identifier for the Response
# * LocationID - Location Identifier
# * TopicID
# * QuestionID - Question Identifier
# * DataValueTypeID	- Identifier for the Data Value Type
# * StratificationCategoryID1 - Identifier for stratification category 1
# * StratificationID1 - Identifier for stratification 1
# * StratificationCategoryID2
# * StratificationID2
# * StratificationCategoryID3
# * StratificationID3

# %%
# read chronic diseases indicators csv
CDI_df = pd.read_csv('Resources/U.S._Chronic_Disease_Indicators__CDI_.csv')
CDI_df.shape
# Out:
# C:\Users\ricem\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (7,10,18,19,20,21,23,30,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (519718, 34)

# %% [markdown]
# This dataset contained several columns of missing or not relevant information to the analysis.
#
# The following steps below:
# * removed unnecessary columns that contained missing or repetitive information
# * separated datasets by location of either 'United States' or individual states
# * categorized two larger datasets by either 'Crude Prevalence' or 'Age-adjusted Prevalence', which was then stratified by either overall, male, or female gender types ('Stratification1' column).
# * separated each gender type by year (2013, 2014, 2015, 2016)

# %%
## CLEAN UP DATAFRAME
# Select desired columns
CDI_df = CDI_df[['YearStart', 'LocationAbbr', 'LocationDesc', 'Topic', 'DataValue', 'DataValueUnit', 'DataValueType', 'StratificationCategory1', 'Stratification1']]

CDI_df.shape
# Out:
# (519718, 9)

# %%
# Drop any other rows with missing data
CDI_df = CDI_df.dropna(subset = ['DataValue', 'DataValueUnit'])
CDI_df.shape
# Out:
# (336660, 9)

# %%
# Remove rows where 'DataValue' == ' '
CDI_df = CDI_df.loc[CDI_df['DataValue'] != ' ']

# %%
# Convert DataValue from string to float

CDI_df.DataValue = [float(x) for x in CDI_df.DataValue]
CDI_df.head()
# Out:
#    YearStart LocationAbbr   LocationDesc    Topic  DataValue DataValueUnit  \
# 0       2016           US  United States  Alcohol       16.9             %
# 1       2016           AL        Alabama  Alcohol       13.0             %
# 2       2016           AK         Alaska  Alcohol       18.2             %
# 3       2016           AZ        Arizona  Alcohol       15.6             %
# 4       2016           AR       Arkansas  Alcohol       15.0             %
#
#       DataValueType StratificationCategory1 Stratification1
# 0  Crude Prevalence                 Overall         Overall
# 1  Crude Prevalence                 Overall         Overall
# 2  Crude Prevalence                 Overall         Overall
# 3  Crude Prevalence                 Overall         Overall
# 4  Crude Prevalence                 Overall         Overall

# %% [markdown]
# ## Chronic Disease Indicators by United States

# %% [markdown]
# Next we observed the chronic disease indicators for the United States only. This dataset describes the disease prevalence present in the United States and for the individual states. The following shows the process we used to clean the dataset to observe the disease prevalence in the United States only for the years 2013 to 2016.
#
# Below are the results for the prevalence of each year for United States only.

# %%
# Obtain rows only for the all of the United States
CDI_US = CDI_df.loc[CDI_df['LocationAbbr']=="US",:]
CDI_US
# Out:
#         YearStart LocationAbbr   LocationDesc                   Topic  \
# 0            2016           US  United States                 Alcohol
# 55           2016           US  United States                 Alcohol
# 110          2016           US  United States                 Alcohol
# 165          2016           US  United States                 Alcohol
# 220          2016           US  United States                 Alcohol
# 275          2016           US  United States                 Alcohol
# 874          2016           US  United States                 Alcohol
# 1201         2016           US  United States                 Alcohol
# 1254         2016           US  United States                 Alcohol
# 1310         2016           US  United States                 Alcohol
# 1365         2016           US  United States                 Alcohol
# 1420         2016           US  United States                 Alcohol
# 1475         2016           US  United States                 Alcohol
# 1935         2016           US  United States                 Alcohol
# 2125         2016           US  United States                 Alcohol
# 2180         2016           US  United States                 Alcohol
# 2235         2016           US  United States                 Alcohol
# 2290         2016           US  United States                 Alcohol
# 2345         2016           US  United States                 Alcohol
# 2943         2016           US  United States                 Alcohol
# 2990         2016           US  United States                 Alcohol
# 3045         2016           US  United States                 Alcohol
# 3100         2016           US  United States                 Alcohol
# 3155         2016           US  United States                 Alcohol
# 3210         2016           US  United States                 Alcohol
# 3806         2016           US  United States                 Alcohol
# 4134         2016           US  United States               Arthritis
# 4185         2016           US  United States               Arthritis
# 4240         2016           US  United States               Arthritis
# 4295         2016           US  United States               Arthritis
# ...           ...          ...            ...                     ...
# 517482       2016           US  United States  Overarching Conditions
# 517483       2016           US  United States  Overarching Conditions
# 517484       2016           US  United States  Overarching Conditions
# 517485       2016           US  United States  Overarching Conditions
# 517486       2016           US  United States  Overarching Conditions
# 517487       2016           US  United States  Overarching Conditions
# 517488       2016           US  United States  Overarching Conditions
# 517489       2016           US  United States  Overarching Conditions
# 517599       2016           US  United States  Overarching Conditions
# 517655       2016           US  United States  Overarching Conditions
# 517711       2016           US  United States  Overarching Conditions
# 517766       2015           US  United States  Overarching Conditions
# 517822       2015           US  United States  Overarching Conditions
# 517932       2014           US  United States  Overarching Conditions
# 517987       2014           US  United States  Overarching Conditions
# 518043       2014           US  United States  Overarching Conditions
# 518098       2013           US  United States  Overarching Conditions
# 518153       2013           US  United States  Overarching Conditions
# 518208       2013           US  United States  Overarching Conditions
# 518254       2012           US  United States  Overarching Conditions
# 518307       2012           US  United States  Overarching Conditions
# 518361       2012           US  United States  Overarching Conditions
# 518429       2011           US  United States  Overarching Conditions
# 518486       2011           US  United States  Overarching Conditions
# 518544       2011           US  United States  Overarching Conditions
# 518654       2010           US  United States  Overarching Conditions
# 518712       2010           US  United States  Overarching Conditions
# 519176       2012           US  United States           Mental Health
# 519230       2012           US  United States           Mental Health
# 519281       2012           US  United States           Mental Health
#
#         DataValue DataValueUnit            DataValueType  \
# 0            16.9             %         Crude Prevalence
# 55           17.9             %  Age-adjusted Prevalence
# 110          21.9             %         Crude Prevalence
# 165          22.5             %  Age-adjusted Prevalence
# 220          12.0             %         Crude Prevalence
# 275          13.1             %  Age-adjusted Prevalence
# 874          18.7             %         Crude Prevalence
# 1201          4.6        Number                     Mean
# 1254          4.7        Number        Age-adjusted Mean
# 1310          5.0        Number                     Mean
# 1365          5.0        Number        Age-adjusted Mean
# 1420          3.5        Number                     Mean
# 1475          3.6        Number        Age-adjusted Mean
# 1935          7.4        Number                     Mean
# 2125          7.1        Number        Age-adjusted Mean
# 2180          8.5        Number                     Mean
# 2235          8.2        Number        Age-adjusted Mean
# 2290          5.6        Number                     Mean
# 2345          5.3        Number        Age-adjusted Mean
# 2943          6.5             %         Crude Prevalence
# 2990          6.7             %  Age-adjusted Prevalence
# 3045          7.1             %         Crude Prevalence
# 3100          7.2             %  Age-adjusted Prevalence
# 3155          5.9             %         Crude Prevalence
# 3210          6.0             %  Age-adjusted Prevalence
# 3806          6.6             %         Crude Prevalence
# 4134         25.8             %         Crude Prevalence
# 4185         23.9             %  Age-adjusted Prevalence
# 4240         22.1             %         Crude Prevalence
# 4295         20.9             %  Age-adjusted Prevalence
# ...           ...           ...                      ...
# 517482       12.8             %         Crude Prevalence
# 517483       15.2             %         Crude Prevalence
# 517484       14.0             %         Crude Prevalence
# 517485       10.0             %         Crude Prevalence
# 517486       23.8             %         Crude Prevalence
# 517487       21.0             %         Crude Prevalence
# 517488       26.9             %         Crude Prevalence
# 517489       11.7             %         Crude Prevalence
# 517599       86.9             %         Crude Prevalence
# 517655       85.1             %         Crude Prevalence
# 517711       88.7             %         Crude Prevalence
# 517766       86.5             %         Crude Prevalence
# 517822       84.5             %         Crude Prevalence
# 517932       86.1             %         Crude Prevalence
# 517987       88.2             %         Crude Prevalence
# 518043       84.1             %         Crude Prevalence
# 518098       85.3             %         Crude Prevalence
# 518153       83.2             %         Crude Prevalence
# 518208       87.7             %         Crude Prevalence
# 518254       85.2             %         Crude Prevalence
# 518307       83.0             %         Crude Prevalence
# 518361       87.5             %         Crude Prevalence
# 518429       84.1             %         Crude Prevalence
# 518486       81.6             %         Crude Prevalence
# 518544       86.8             %         Crude Prevalence
# 518654       80.4             %         Crude Prevalence
# 518712       86.1             %         Crude Prevalence
# 519176        3.8        Number                     Mean
# 519230        3.3        Number                     Mean
# 519281        4.4        Number                     Mean
#
#        StratificationCategory1                   Stratification1
# 0                      Overall                           Overall
# 55                     Overall                           Overall
# 110                     Gender                              Male
# 165                     Gender                              Male
# 220                     Gender                            Female
# 275                     Gender                            Female
# 874                    Overall                           Overall
# 1201                   Overall                           Overall
# 1254                   Overall                           Overall
# 1310                    Gender                              Male
# 1365                    Gender                              Male
# 1420                    Gender                            Female
# 1475                    Gender                            Female
# 1935                   Overall                           Overall
# 2125                   Overall                           Overall
# 2180                    Gender                              Male
# 2235                    Gender                              Male
# 2290                    Gender                            Female
# 2345                    Gender                            Female
# 2943                   Overall                           Overall
# 2990                   Overall                           Overall
# 3045                    Gender                              Male
# 3100                    Gender                              Male
# 3155                    Gender                            Female
# 3210                    Gender                            Female
# 3806                   Overall                           Overall
# 4134                   Overall                           Overall
# 4185                   Overall                           Overall
# 4240                    Gender                              Male
# 4295                    Gender                              Male
# ...                        ...                               ...
# 517482                  Gender                              Male
# 517483                  Gender                            Female
# 517484                 Overall                           Overall
# 517485          Race/Ethnicity               White, non-Hispanic
# 517486          Race/Ethnicity               Black, non-Hispanic
# 517487          Race/Ethnicity                          Hispanic
# 517488          Race/Ethnicity  American Indian or Alaska Native
# 517489          Race/Ethnicity               Asian, non-Hispanic
# 517599                 Overall                           Overall
# 517655                  Gender                              Male
# 517711                  Gender                            Female
# 517766                 Overall                           Overall
# 517822                  Gender                              Male
# 517932                 Overall                           Overall
# 517987                  Gender                              Male
# 518043                  Gender                            Female
# 518098                 Overall                           Overall
# 518153                  Gender                              Male
# 518208                  Gender                            Female
# 518254                 Overall                           Overall
# 518307                  Gender                              Male
# 518361                  Gender                            Female
# 518429                 Overall                           Overall
# 518486                  Gender                              Male
# 518544                  Gender                            Female
# 518654                  Gender                              Male
# 518712                  Gender                            Female
# 519176                 Overall                           Overall
# 519230                  Gender                              Male
# 519281                  Gender                            Female
#
# [3123 rows x 9 columns]

# %%
# Obtain rows only for the years =2013
CDI_US_2013 = CDI_US.loc[CDI_US['YearStart']==2013, :]
CDI_US_2013
# Out:
#         YearStart LocationAbbr   LocationDesc  \
# 125505       2013           US  United States
# 125916       2013           US  United States
# 126417       2013           US  United States
# 126469       2013           US  United States
# 126521       2013           US  United States
# 126573       2013           US  United States
# 129745       2013           US  United States
# 129746       2013           US  United States
# 129747       2013           US  United States
# 130183       2013           US  United States
# 130184       2013           US  United States
# 130185       2013           US  United States
# 130622       2013           US  United States
# 130623       2013           US  United States
# 130624       2013           US  United States
# 131061       2013           US  United States
# 131062       2013           US  United States
# 131063       2013           US  United States
# 132703       2013           US  United States
# 132704       2013           US  United States
# 132705       2013           US  United States
# 133141       2013           US  United States
# 133142       2013           US  United States
# 133143       2013           US  United States
# 133583       2013           US  United States
# 133584       2013           US  United States
# 133585       2013           US  United States
# 134017       2013           US  United States
# 134018       2013           US  United States
# 134019       2013           US  United States
# ...           ...          ...            ...
# 503810       2013           US  United States
# 503865       2013           US  United States
# 504466       2013           US  United States
# 504519       2013           US  United States
# 504574       2013           US  United States
# 504631       2013           US  United States
# 504686       2013           US  United States
# 504742       2013           US  United States
# 505344       2013           US  United States
# 505394       2013           US  United States
# 505450       2013           US  United States
# 505506       2013           US  United States
# 505561       2013           US  United States
# 505617       2013           US  United States
# 510996       2013           US  United States
# 511176       2013           US  United States
# 511231       2013           US  United States
# 511286       2013           US  United States
# 511341       2013           US  United States
# 511396       2013           US  United States
# 511994       2013           US  United States
# 515842       2013           US  United States
# 515896       2013           US  United States
# 515952       2013           US  United States
# 516007       2013           US  United States
# 516062       2013           US  United States
# 516117       2013           US  United States
# 518098       2013           US  United States
# 518153       2013           US  United States
# 518208       2013           US  United States
#
#                                                   Topic  DataValue  \
# 125505                                           Asthma       10.7
# 125916                                           Asthma       11.5
# 126417                           Chronic Kidney Disease      326.3
# 126469                           Chronic Kidney Disease   115877.0
# 126521                           Chronic Kidney Disease      144.8
# 126573                           Chronic Kidney Disease    51070.0
# 129745                           Cardiovascular Disease       80.4
# 129746                           Cardiovascular Disease       76.7
# 129747                           Cardiovascular Disease       78.5
# 130183                           Cardiovascular Disease       82.2
# 130184                           Cardiovascular Disease       77.4
# 130185                           Cardiovascular Disease       80.1
# 130622                           Cardiovascular Disease       31.4
# 130623                           Cardiovascular Disease       35.1
# 130624                           Cardiovascular Disease       33.3
# 131061                           Cardiovascular Disease       38.4
# 131062                           Cardiovascular Disease       39.9
# 131063                           Cardiovascular Disease       36.7
# 132703  Nutrition, Physical Activity, and Weight Status        1.1
# 132704  Nutrition, Physical Activity, and Weight Status        1.0
# 132705  Nutrition, Physical Activity, and Weight Status        1.0
# 133141  Nutrition, Physical Activity, and Weight Status        1.4
# 133142  Nutrition, Physical Activity, and Weight Status        1.3
# 133143  Nutrition, Physical Activity, and Weight Status        1.3
# 133583                                          Tobacco       66.5
# 133584                                          Tobacco       64.4
# 133585                                          Tobacco       65.4
# 134017                                          Tobacco       66.8
# 134018                                          Tobacco       65.0
# 134019                                          Tobacco       65.9
# ...                                                 ...        ...
# 503810                                        Arthritis       50.4
# 503865                                        Arthritis       51.9
# 504466                                        Arthritis       39.9
# 504519                                        Arthritis       40.5
# 504574                                        Arthritis       39.0
# 504631                                        Arthritis       39.0
# 504686                                        Arthritis       40.9
# 504742                                        Arthritis       42.8
# 505344                                        Arthritis       28.3
# 505394                                        Arthritis       29.5
# 505450                                        Arthritis       22.4
# 505506                                        Arthritis       24.3
# 505561                                        Arthritis       32.5
# 505617                                        Arthritis       33.0
# 510996                                          Alcohol        6.2
# 511176                                          Alcohol        6.2
# 511231                                          Alcohol        6.6
# 511286                                          Alcohol        6.6
# 511341                                          Alcohol        5.2
# 511396                                          Alcohol        5.2
# 511994                                          Alcohol        5.9
# 515842                                     Immunization       40.3
# 515896                                     Immunization       38.8
# 515952                                     Immunization       36.2
# 516007                                     Immunization       35.0
# 516062                                     Immunization       43.7
# 516117                                     Immunization       41.8
# 518098                           Overarching Conditions       85.3
# 518153                           Overarching Conditions       83.2
# 518208                           Overarching Conditions       87.7
#
#               DataValueUnit                             DataValueType  \
# 125505  cases per 1,000,000                         Age-adjusted Rate
# 125916  cases per 1,000,000                                Crude Rate
# 126417  cases per 1,000,000  Adjusted by age, sex, race and ethnicity
# 126469  cases per 1,000,000                                    Number
# 126521  cases per 1,000,000  Adjusted by age, sex, race and ethnicity
# 126573  cases per 1,000,000                                    Number
# 129745                    %                   Age-adjusted Prevalence
# 129746                    %                   Age-adjusted Prevalence
# 129747                    %                   Age-adjusted Prevalence
# 130183                    %                          Crude Prevalence
# 130184                    %                          Crude Prevalence
# 130185                    %                          Crude Prevalence
# 130622                    %                   Age-adjusted Prevalence
# 130623                    %                   Age-adjusted Prevalence
# 130624                    %                   Age-adjusted Prevalence
# 131061                    %                          Crude Prevalence
# 131062                    %                          Crude Prevalence
# 131063                    %                          Crude Prevalence
# 132703               Number                                    Median
# 132704               Number                                    Median
# 132705               Number                                    Median
# 133141               Number                                    Median
# 133142               Number                                    Median
# 133143               Number                                    Median
# 133583                    %                   Age-adjusted Prevalence
# 133584                    %                   Age-adjusted Prevalence
# 133585                    %                   Age-adjusted Prevalence
# 134017                    %                          Crude Prevalence
# 134018                    %                          Crude Prevalence
# 134019                    %                          Crude Prevalence
# ...                     ...                                       ...
# 503810                    %                          Crude Prevalence
# 503865                    %                   Age-adjusted Prevalence
# 504466                    %                          Crude Prevalence
# 504519                    %                   Age-adjusted Prevalence
# 504574                    %                          Crude Prevalence
# 504631                    %                   Age-adjusted Prevalence
# 504686                    %                          Crude Prevalence
# 504742                    %                   Age-adjusted Prevalence
# 505344                    %                          Crude Prevalence
# 505394                    %                   Age-adjusted Prevalence
# 505450                    %                          Crude Prevalence
# 505506                    %                   Age-adjusted Prevalence
# 505561                    %                          Crude Prevalence
# 505617                    %                   Age-adjusted Prevalence
# 510996                    %                          Crude Prevalence
# 511176                    %                   Age-adjusted Prevalence
# 511231                    %                          Crude Prevalence
# 511286                    %                   Age-adjusted Prevalence
# 511341                    %                          Crude Prevalence
# 511396                    %                   Age-adjusted Prevalence
# 511994                    %                          Crude Prevalence
# 515842                    %                          Crude Prevalence
# 515896                    %                   Age-adjusted Prevalence
# 515952                    %                          Crude Prevalence
# 516007                    %                   Age-adjusted Prevalence
# 516062                    %                          Crude Prevalence
# 516117                    %                   Age-adjusted Prevalence
# 518098                    %                          Crude Prevalence
# 518153                    %                          Crude Prevalence
# 518208                    %                          Crude Prevalence
#
#        StratificationCategory1 Stratification1
# 125505                 Overall         Overall
# 125916                 Overall         Overall
# 126417                 Overall         Overall
# 126469                 Overall         Overall
# 126521                 Overall         Overall
# 126573                 Overall         Overall
# 129745                  Gender          Female
# 129746                  Gender            Male
# 129747                 Overall         Overall
# 130183                  Gender          Female
# 130184                  Gender            Male
# 130185                 Overall         Overall
# 130622                  Gender          Female
# 130623                  Gender            Male
# 130624                 Overall         Overall
# 131061                 Overall         Overall
# 131062                  Gender            Male
# 131063                  Gender          Female
# 132703                  Gender          Female
# 132704                  Gender            Male
# 132705                 Overall         Overall
# 133141                  Gender          Female
# 133142                  Gender            Male
# 133143                 Overall         Overall
# 133583                  Gender          Female
# 133584                  Gender            Male
# 133585                 Overall         Overall
# 134017                  Gender          Female
# 134018                  Gender            Male
# 134019                 Overall         Overall
# ...                        ...             ...
# 503810                  Gender          Female
# 503865                  Gender          Female
# 504466                 Overall         Overall
# 504519                 Overall         Overall
# 504574                  Gender            Male
# 504631                  Gender            Male
# 504686                  Gender          Female
# 504742                  Gender          Female
# 505344                 Overall         Overall
# 505394                 Overall         Overall
# 505450                  Gender            Male
# 505506                  Gender            Male
# 505561                  Gender          Female
# 505617                  Gender          Female
# 510996                 Overall         Overall
# 511176                 Overall         Overall
# 511231                  Gender            Male
# 511286                  Gender            Male
# 511341                  Gender          Female
# 511396                  Gender          Female
# 511994                 Overall         Overall
# 515842                 Overall         Overall
# 515896                 Overall         Overall
# 515952                  Gender            Male
# 516007                  Gender            Male
# 516062                  Gender          Female
# 516117                  Gender          Female
# 518098                 Overall         Overall
# 518153                  Gender            Male
# 518208                  Gender          Female
#
# [556 rows x 9 columns]

# %%
# Obtain rows only for the years =2014
CDI_US_2014 = CDI_US.loc[CDI_US['YearStart']==2014, :]
CDI_US_2014
# Out:
#         YearStart LocationAbbr   LocationDesc  \
# 117329       2014           US  United States
# 119724       2014           US  United States
# 119820       2014           US  United States
# 119871       2014           US  United States
# 120252       2014           US  United States
# 120253       2014           US  United States
# 120254       2014           US  United States
# 120696       2014           US  United States
# 120697       2014           US  United States
# 120698       2014           US  United States
# 121139       2014           US  United States
# 121140       2014           US  United States
# 121141       2014           US  United States
# 121582       2014           US  United States
# 121583       2014           US  United States
# 121584       2014           US  United States
# 122023       2014           US  United States
# 122024       2014           US  United States
# 122025       2014           US  United States
# 122461       2014           US  United States
# 122462       2014           US  United States
# 122463       2014           US  United States
# 122531       2014           US  United States
# 122887       2014           US  United States
# 122888       2014           US  United States
# 122889       2014           US  United States
# 123317       2014           US  United States
# 123318       2014           US  United States
# 123319       2014           US  United States
# 124003       2014           US  United States
# ...           ...          ...            ...
# 480003       2014           US  United States
# 480004       2014           US  United States
# 480005       2014           US  United States
# 480006       2014           US  United States
# 480007       2014           US  United States
# 480008       2014           US  United States
# 480009       2014           US  United States
# 480010       2014           US  United States
# 500023       2014           US  United States
# 500078       2014           US  United States
# 500133       2014           US  United States
# 500464       2014           US  United States
# 500517       2014           US  United States
# 500572       2014           US  United States
# 509931       2014           US  United States
# 509981       2014           US  United States
# 510036       2014           US  United States
# 510091       2014           US  United States
# 510146       2014           US  United States
# 510201       2014           US  United States
# 510800       2014           US  United States
# 514949       2014           US  United States
# 515006       2014           US  United States
# 515061       2014           US  United States
# 515116       2014           US  United States
# 515171       2014           US  United States
# 515227       2014           US  United States
# 517932       2014           US  United States
# 517987       2014           US  United States
# 518043       2014           US  United States
#
#                                                   Topic  DataValue  \
# 117329                           Chronic Kidney Disease  118014.00
# 119724                           Chronic Kidney Disease     327.50
# 119820                           Chronic Kidney Disease     146.00
# 119871                           Chronic Kidney Disease   52159.00
# 120252                           Cardiovascular Disease      48.90
# 120253                           Cardiovascular Disease      44.80
# 120254                           Cardiovascular Disease      47.10
# 120696                           Cardiovascular Disease      81.40
# 120697                           Cardiovascular Disease      77.50
# 120698                           Cardiovascular Disease      79.40
# 121139                           Cardiovascular Disease      82.60
# 121140                           Cardiovascular Disease      77.40
# 121141                           Cardiovascular Disease      79.40
# 121582                           Cardiovascular Disease      46.30
# 121583                           Cardiovascular Disease      42.10
# 121584                           Cardiovascular Disease      43.30
# 122023                           Cardiovascular Disease      62.60
# 122024                           Cardiovascular Disease      64.40
# 122025                           Cardiovascular Disease      64.50
# 122461                           Cardiovascular Disease      63.40
# 122462                           Cardiovascular Disease      64.10
# 122463                           Cardiovascular Disease      64.60
# 122531                                         Diabetes       5.70
# 122887  Nutrition, Physical Activity, and Weight Status      30.00
# 122888  Nutrition, Physical Activity, and Weight Status      29.30
# 122889  Nutrition, Physical Activity, and Weight Status      29.80
# 123317  Nutrition, Physical Activity, and Weight Status      29.30
# 123318  Nutrition, Physical Activity, and Weight Status      29.40
# 123319  Nutrition, Physical Activity, and Weight Status      29.60
# 124003                                          Tobacco      67.60
# ...                                                 ...        ...
# 480003                                     Older Adults       9.34
# 480004                                     Older Adults       6.38
# 480005                                     Older Adults      11.43
# 480006                                     Older Adults       9.93
# 480007                                     Older Adults       4.83
# 480008                                     Older Adults       8.42
# 480009                                     Older Adults       4.94
# 480010                                     Older Adults       8.97
# 500023                           Cardiovascular Disease      38.10
# 500078                           Cardiovascular Disease      37.70
# 500133                           Cardiovascular Disease      41.30
# 500464                           Cardiovascular Disease      36.50
# 500517                           Cardiovascular Disease      34.60
# 500572                           Cardiovascular Disease      39.50
# 509931                                          Alcohol       5.90
# 509981                                          Alcohol       6.00
# 510036                                          Alcohol       6.80
# 510091                                          Alcohol       6.90
# 510146                                          Alcohol       5.30
# 510201                                          Alcohol       5.40
# 510800                                          Alcohol       5.80
# 514949                                     Immunization      40.40
# 515006                                     Immunization      39.40
# 515061                                     Immunization      36.20
# 515116                                     Immunization      35.30
# 515171                                     Immunization      43.70
# 515227                                     Immunization      42.30
# 517932                           Overarching Conditions      86.10
# 517987                           Overarching Conditions      88.20
# 518043                           Overarching Conditions      84.10
#
#               DataValueUnit                             DataValueType  \
# 117329  cases per 1,000,000                                    Number
# 119724  cases per 1,000,000  Adjusted by age, sex, race and ethnicity
# 119820  cases per 1,000,000  Adjusted by age, sex, race and ethnicity
# 119871  cases per 1,000,000                                    Number
# 120252                    %                          Crude Prevalence
# 120253                    %                          Crude Prevalence
# 120254                    %                          Crude Prevalence
# 120696                    %                   Age-adjusted Prevalence
# 120697                    %                   Age-adjusted Prevalence
# 120698                    %                   Age-adjusted Prevalence
# 121139                    %                          Crude Prevalence
# 121140                    %                          Crude Prevalence
# 121141                    %                          Crude Prevalence
# 121582                    %                          Crude Prevalence
# 121583                    %                          Crude Prevalence
# 121584                    %                          Crude Prevalence
# 122023                    %                   Age-adjusted Prevalence
# 122024                    %                   Age-adjusted Prevalence
# 122025                    %                   Age-adjusted Prevalence
# 122461                    %                          Crude Prevalence
# 122462                    %                          Crude Prevalence
# 122463                    %                          Crude Prevalence
# 122531                    %                          Crude Prevalence
# 122887                    %                   Age-adjusted Prevalence
# 122888                    %                   Age-adjusted Prevalence
# 122889                    %                   Age-adjusted Prevalence
# 123317                    %                          Crude Prevalence
# 123318                    %                          Crude Prevalence
# 123319                    %                          Crude Prevalence
# 124003                    %                   Age-adjusted Prevalence
# ...                     ...                                       ...
# 480003      cases per 1,000                         Age-adjusted Rate
# 480004      cases per 1,000                         Age-adjusted Rate
# 480005      cases per 1,000                         Age-adjusted Rate
# 480006      cases per 1,000                         Age-adjusted Rate
# 480007      cases per 1,000                         Age-adjusted Rate
# 480008      cases per 1,000                         Age-adjusted Rate
# 480009      cases per 1,000                         Age-adjusted Rate
# 480010      cases per 1,000                         Age-adjusted Rate
# 500023                    %                   Age-adjusted Prevalence
# 500078                    %                   Age-adjusted Prevalence
# 500133                    %                   Age-adjusted Prevalence
# 500464                    %                   Age-adjusted Prevalence
# 500517                    %                   Age-adjusted Prevalence
# 500572                    %                   Age-adjusted Prevalence
# 509931                    %                          Crude Prevalence
# 509981                    %                   Age-adjusted Prevalence
# 510036                    %                          Crude Prevalence
# 510091                    %                   Age-adjusted Prevalence
# 510146                    %                          Crude Prevalence
# 510201                    %                   Age-adjusted Prevalence
# 510800                    %                          Crude Prevalence
# 514949                    %                          Crude Prevalence
# 515006                    %                   Age-adjusted Prevalence
# 515061                    %                          Crude Prevalence
# 515116                    %                   Age-adjusted Prevalence
# 515171                    %                          Crude Prevalence
# 515227                    %                   Age-adjusted Prevalence
# 517932                    %                          Crude Prevalence
# 517987                    %                          Crude Prevalence
# 518043                    %                          Crude Prevalence
#
#        StratificationCategory1                   Stratification1
# 117329                 Overall                           Overall
# 119724                 Overall                           Overall
# 119820                 Overall                           Overall
# 119871                 Overall                           Overall
# 120252                  Gender                            Female
# 120253                  Gender                              Male
# 120254                 Overall                           Overall
# 120696                  Gender                            Female
# 120697                  Gender                              Male
# 120698                 Overall                           Overall
# 121139                  Gender                            Female
# 121140                  Gender                              Male
# 121141                 Overall                           Overall
# 121582                  Gender                            Female
# 121583                  Gender                              Male
# 121584                 Overall                           Overall
# 122023                  Gender                            Female
# 122024                  Gender                              Male
# 122025                 Overall                           Overall
# 122461                  Gender                            Female
# 122462                  Gender                              Male
# 122463                 Overall                           Overall
# 122531                 Overall                           Overall
# 122887                  Gender                            Female
# 122888                  Gender                              Male
# 122889                 Overall                           Overall
# 123317                  Gender                            Female
# 123318                  Gender                              Male
# 123319                 Overall                           Overall
# 124003                  Gender                            Female
# ...                        ...                               ...
# 480003                 Overall                           Overall
# 480004                  Gender                              Male
# 480005                  Gender                            Female
# 480006          Race/Ethnicity               White, non-Hispanic
# 480007          Race/Ethnicity               Black, non-Hispanic
# 480008          Race/Ethnicity                          Hispanic
# 480009          Race/Ethnicity         Asian or Pacific Islander
# 480010          Race/Ethnicity  American Indian or Alaska Native
# 500023                 Overall                           Overall
# 500078                  Gender                              Male
# 500133                  Gender                            Female
# 500464                 Overall                           Overall
# 500517                  Gender                              Male
# 500572                  Gender                            Female
# 509931                 Overall                           Overall
# 509981                 Overall                           Overall
# 510036                  Gender                              Male
# 510091                  Gender                              Male
# 510146                  Gender                            Female
# 510201                  Gender                            Female
# 510800                 Overall                           Overall
# 514949                 Overall                           Overall
# 515006                 Overall                           Overall
# 515061                  Gender                              Male
# 515116                  Gender                              Male
# 515171                  Gender                            Female
# 515227                  Gender                            Female
# 517932                 Overall                           Overall
# 517987                  Gender                              Male
# 518043                  Gender                            Female
#
# [489 rows x 9 columns]

# %%
# Obtain rows only for the years =2015
CDI_US_2015 = CDI_US.loc[CDI_US['YearStart']==2015, :]
CDI_US_2015
# Out:
#         YearStart LocationAbbr   LocationDesc                   Topic  \
# 58824        2015           US  United States                 Alcohol
# 58875        2015           US  United States                 Alcohol
# 59257        2015           US  United States                 Alcohol
# 59258        2015           US  United States                 Alcohol
# 59259        2015           US  United States                 Alcohol
# 59694        2015           US  United States                 Alcohol
# 59695        2015           US  United States                 Alcohol
# 59696        2015           US  United States                 Alcohol
# 60036        2015           US  United States                 Alcohol
# 60459        2015           US  United States                 Alcohol
# 60460        2015           US  United States                 Alcohol
# 60461        2015           US  United States                 Alcohol
# 60893        2015           US  United States                 Alcohol
# 60894        2015           US  United States                 Alcohol
# 60895        2015           US  United States                 Alcohol
# 61331        2015           US  United States                 Alcohol
# 61332        2015           US  United States                 Alcohol
# 61333        2015           US  United States                 Alcohol
# 61766        2015           US  United States                 Alcohol
# 61767        2015           US  United States                 Alcohol
# 61768        2015           US  United States                 Alcohol
# 62195        2015           US  United States               Arthritis
# 62196        2015           US  United States               Arthritis
# 62197        2015           US  United States               Arthritis
# 62625        2015           US  United States               Arthritis
# 62626        2015           US  United States               Arthritis
# 62627        2015           US  United States               Arthritis
# 63061        2015           US  United States               Arthritis
# 63062        2015           US  United States               Arthritis
# 63063        2015           US  United States               Arthritis
# ...           ...          ...            ...                     ...
# 475024       2015           US  United States            Older Adults
# 475025       2015           US  United States            Older Adults
# 498480       2015           US  United States                 Alcohol
# 500959       2015           US  United States               Arthritis
# 501011       2015           US  United States               Arthritis
# 501067       2015           US  United States               Arthritis
# 501121       2015           US  United States               Arthritis
# 501176       2015           US  United States               Arthritis
# 501231       2015           US  United States               Arthritis
# 501834       2015           US  United States               Arthritis
# 501888       2015           US  United States               Arthritis
# 501943       2015           US  United States               Arthritis
# 501999       2015           US  United States               Arthritis
# 502054       2015           US  United States               Arthritis
# 502109       2015           US  United States               Arthritis
# 502712       2015           US  United States               Arthritis
# 502764       2015           US  United States               Arthritis
# 502820       2015           US  United States               Arthritis
# 502875       2015           US  United States               Arthritis
# 502930       2015           US  United States               Arthritis
# 502985       2015           US  United States               Arthritis
# 508845       2015           US  United States                 Alcohol
# 508872       2015           US  United States                 Alcohol
# 508896       2015           US  United States                 Alcohol
# 508951       2015           US  United States                 Alcohol
# 509006       2015           US  United States                 Alcohol
# 509609       2015           US  United States                 Alcohol
# 514970       2015           US  United States  Overarching Conditions
# 517766       2015           US  United States  Overarching Conditions
# 517822       2015           US  United States  Overarching Conditions
#
#         DataValue    DataValueUnit            DataValueType  \
# 58824       32.80                %         Crude Prevalence
# 58875       17.70                %         Crude Prevalence
# 59257       12.60                %  Age-adjusted Prevalence
# 59258       22.00                %  Age-adjusted Prevalence
# 59259       17.00                %  Age-adjusted Prevalence
# 59694       11.70                %         Crude Prevalence
# 59695       21.40                %         Crude Prevalence
# 59696       16.30                %         Crude Prevalence
# 60036       17.70                %         Crude Prevalence
# 60459        3.40           Number        Age-adjusted Mean
# 60460        5.00           Number        Age-adjusted Mean
# 60461        4.50           Number        Age-adjusted Mean
# 60893        3.30           Number                     Mean
# 60894        4.80           Number                     Mean
# 60895        4.30           Number                     Mean
# 61331        5.30           Number        Age-adjusted Mean
# 61332        8.10           Number        Age-adjusted Mean
# 61333        7.20           Number        Age-adjusted Mean
# 61766        5.60           Number                     Mean
# 61767        8.50           Number                     Mean
# 61768        7.50           Number                     Mean
# 62195       25.80                %  Age-adjusted Prevalence
# 62196       20.90                %  Age-adjusted Prevalence
# 62197       23.40                %  Age-adjusted Prevalence
# 62625       29.00                %         Crude Prevalence
# 62626       22.00                %         Crude Prevalence
# 62627       25.30                %         Crude Prevalence
# 63061       34.00                %  Age-adjusted Prevalence
# 63062       25.70                %  Age-adjusted Prevalence
# 63063       30.10                %  Age-adjusted Prevalence
# ...           ...              ...                      ...
# 475024       4.04  cases per 1,000        Age-adjusted Rate
# 475025       6.44  cases per 1,000        Age-adjusted Rate
# 498480       6.00                %  Age-adjusted Prevalence
# 500959      49.00                %         Crude Prevalence
# 501011      49.60                %  Age-adjusted Prevalence
# 501067      46.30                %         Crude Prevalence
# 501121      45.80                %  Age-adjusted Prevalence
# 501176      51.10                %         Crude Prevalence
# 501231      51.70                %  Age-adjusted Prevalence
# 501834      42.10                %         Crude Prevalence
# 501888      42.70                %  Age-adjusted Prevalence
# 501943      38.30                %         Crude Prevalence
# 501999      38.70                %  Age-adjusted Prevalence
# 502054      43.20                %         Crude Prevalence
# 502109      42.70                %  Age-adjusted Prevalence
# 502712      28.40                %         Crude Prevalence
# 502764      29.50                %  Age-adjusted Prevalence
# 502820      23.20                %         Crude Prevalence
# 502875      24.30                %  Age-adjusted Prevalence
# 502930      31.90                %         Crude Prevalence
# 502985      32.30                %  Age-adjusted Prevalence
# 508845       5.90                %         Crude Prevalence
# 508872       6.40                %         Crude Prevalence
# 508896       6.40                %  Age-adjusted Prevalence
# 508951       5.10                %         Crude Prevalence
# 509006       5.30                %  Age-adjusted Prevalence
# 509609       5.60                %         Crude Prevalence
# 514970      88.60                %         Crude Prevalence
# 517766      86.50                %         Crude Prevalence
# 517822      84.50                %         Crude Prevalence
#
#        StratificationCategory1                   Stratification1
# 58824                  Overall                           Overall
# 58875                  Overall                           Overall
# 59257                   Gender                            Female
# 59258                   Gender                              Male
# 59259                  Overall                           Overall
# 59694                   Gender                            Female
# 59695                   Gender                              Male
# 59696                  Overall                           Overall
# 60036                  Overall                           Overall
# 60459                   Gender                            Female
# 60460                   Gender                              Male
# 60461                  Overall                           Overall
# 60893                   Gender                            Female
# 60894                   Gender                              Male
# 60895                  Overall                           Overall
# 61331                   Gender                            Female
# 61332                   Gender                              Male
# 61333                  Overall                           Overall
# 61766                   Gender                            Female
# 61767                   Gender                              Male
# 61768                  Overall                           Overall
# 62195                   Gender                            Female
# 62196                   Gender                              Male
# 62197                  Overall                           Overall
# 62625                   Gender                            Female
# 62626                   Gender                              Male
# 62627                  Overall                           Overall
# 63061                   Gender                            Female
# 63062                   Gender                              Male
# 63063                  Overall                           Overall
# ...                        ...                               ...
# 475024          Race/Ethnicity         Asian or Pacific Islander
# 475025          Race/Ethnicity  American Indian or Alaska Native
# 498480                 Overall                           Overall
# 500959                 Overall                           Overall
# 501011                 Overall                           Overall
# 501067                  Gender                              Male
# 501121                  Gender                              Male
# 501176                  Gender                            Female
# 501231                  Gender                            Female
# 501834                 Overall                           Overall
# 501888                 Overall                           Overall
# 501943                  Gender                              Male
# 501999                  Gender                              Male
# 502054                  Gender                            Female
# 502109                  Gender                            Female
# 502712                 Overall                           Overall
# 502764                 Overall                           Overall
# 502820                  Gender                              Male
# 502875                  Gender                              Male
# 502930                  Gender                            Female
# 502985                  Gender                            Female
# 508845                 Overall                           Overall
# 508872                  Gender                              Male
# 508896                  Gender                              Male
# 508951                  Gender                            Female
# 509006                  Gender                            Female
# 509609                 Overall                           Overall
# 514970                  Gender                            Female
# 517766                 Overall                           Overall
# 517822                  Gender                              Male
#
# [516 rows x 9 columns]

# %%
# Obtain rows only for the years =2016
CDI_US_2016 = CDI_US.loc[CDI_US['YearStart']==2016, :]
CDI_US_2016
# Out:
#         YearStart LocationAbbr   LocationDesc  \
# 0            2016           US  United States
# 55           2016           US  United States
# 110          2016           US  United States
# 165          2016           US  United States
# 220          2016           US  United States
# 275          2016           US  United States
# 874          2016           US  United States
# 1201         2016           US  United States
# 1254         2016           US  United States
# 1310         2016           US  United States
# 1365         2016           US  United States
# 1420         2016           US  United States
# 1475         2016           US  United States
# 1935         2016           US  United States
# 2125         2016           US  United States
# 2180         2016           US  United States
# 2235         2016           US  United States
# 2290         2016           US  United States
# 2345         2016           US  United States
# 2943         2016           US  United States
# 2990         2016           US  United States
# 3045         2016           US  United States
# 3100         2016           US  United States
# 3155         2016           US  United States
# 3210         2016           US  United States
# 3806         2016           US  United States
# 4134         2016           US  United States
# 4185         2016           US  United States
# 4240         2016           US  United States
# 4295         2016           US  United States
# ...           ...          ...            ...
# 57152        2016           US  United States
# 57207        2016           US  United States
# 57263        2016           US  United States
# 57318        2016           US  United States
# 57925        2016           US  United States
# 57970        2016           US  United States
# 58025        2016           US  United States
# 58075        2016           US  United States
# 58130        2016           US  United States
# 58184        2016           US  United States
# 256002       2016           US  United States
# 516299       2016           US  United States
# 517072       2016           US  United States
# 517073       2016           US  United States
# 517074       2016           US  United States
# 517075       2016           US  United States
# 517076       2016           US  United States
# 517077       2016           US  United States
# 517078       2016           US  United States
# 517482       2016           US  United States
# 517483       2016           US  United States
# 517484       2016           US  United States
# 517485       2016           US  United States
# 517486       2016           US  United States
# 517487       2016           US  United States
# 517488       2016           US  United States
# 517489       2016           US  United States
# 517599       2016           US  United States
# 517655       2016           US  United States
# 517711       2016           US  United States
#
#                                                   Topic  DataValue  \
# 0                                               Alcohol       16.9
# 55                                              Alcohol       17.9
# 110                                             Alcohol       21.9
# 165                                             Alcohol       22.5
# 220                                             Alcohol       12.0
# 275                                             Alcohol       13.1
# 874                                             Alcohol       18.7
# 1201                                            Alcohol        4.6
# 1254                                            Alcohol        4.7
# 1310                                            Alcohol        5.0
# 1365                                            Alcohol        5.0
# 1420                                            Alcohol        3.5
# 1475                                            Alcohol        3.6
# 1935                                            Alcohol        7.4
# 2125                                            Alcohol        7.1
# 2180                                            Alcohol        8.5
# 2235                                            Alcohol        8.2
# 2290                                            Alcohol        5.6
# 2345                                            Alcohol        5.3
# 2943                                            Alcohol        6.5
# 2990                                            Alcohol        6.7
# 3045                                            Alcohol        7.1
# 3100                                            Alcohol        7.2
# 3155                                            Alcohol        5.9
# 3210                                            Alcohol        6.0
# 3806                                            Alcohol        6.6
# 4134                                          Arthritis       25.8
# 4185                                          Arthritis       23.9
# 4240                                          Arthritis       22.1
# 4295                                          Arthritis       20.9
# ...                                                 ...        ...
# 57152                                           Tobacco        7.2
# 57207                                           Tobacco        7.4
# 57263                                           Tobacco        1.0
# 57318                                           Tobacco        1.0
# 57925                                           Tobacco       58.4
# 57970                                           Tobacco       58.1
# 58025                                           Tobacco       57.2
# 58075                                           Tobacco       56.3
# 58130                                           Tobacco       59.8
# 58184                                           Tobacco       59.7
# 256002  Nutrition, Physical Activity, and Weight Status       18.3
# 516299                                       Disability       39.0
# 517072                                       Disability       34.7
# 517073                                       Disability       35.6
# 517074                                       Disability       35.7
# 517075                                       Disability       34.3
# 517076                                       Disability       39.9
# 517077                                       Disability       50.2
# 517078                                       Disability       30.4
# 517482                           Overarching Conditions       12.8
# 517483                           Overarching Conditions       15.2
# 517484                           Overarching Conditions       14.0
# 517485                           Overarching Conditions       10.0
# 517486                           Overarching Conditions       23.8
# 517487                           Overarching Conditions       21.0
# 517488                           Overarching Conditions       26.9
# 517489                           Overarching Conditions       11.7
# 517599                           Overarching Conditions       86.9
# 517655                           Overarching Conditions       85.1
# 517711                           Overarching Conditions       88.7
#
#        DataValueUnit            DataValueType StratificationCategory1  \
# 0                  %         Crude Prevalence                 Overall
# 55                 %  Age-adjusted Prevalence                 Overall
# 110                %         Crude Prevalence                  Gender
# 165                %  Age-adjusted Prevalence                  Gender
# 220                %         Crude Prevalence                  Gender
# 275                %  Age-adjusted Prevalence                  Gender
# 874                %         Crude Prevalence                 Overall
# 1201          Number                     Mean                 Overall
# 1254          Number        Age-adjusted Mean                 Overall
# 1310          Number                     Mean                  Gender
# 1365          Number        Age-adjusted Mean                  Gender
# 1420          Number                     Mean                  Gender
# 1475          Number        Age-adjusted Mean                  Gender
# 1935          Number                     Mean                 Overall
# 2125          Number        Age-adjusted Mean                 Overall
# 2180          Number                     Mean                  Gender
# 2235          Number        Age-adjusted Mean                  Gender
# 2290          Number                     Mean                  Gender
# 2345          Number        Age-adjusted Mean                  Gender
# 2943               %         Crude Prevalence                 Overall
# 2990               %  Age-adjusted Prevalence                 Overall
# 3045               %         Crude Prevalence                  Gender
# 3100               %  Age-adjusted Prevalence                  Gender
# 3155               %         Crude Prevalence                  Gender
# 3210               %  Age-adjusted Prevalence                  Gender
# 3806               %         Crude Prevalence                 Overall
# 4134               %         Crude Prevalence                 Overall
# 4185               %  Age-adjusted Prevalence                 Overall
# 4240               %         Crude Prevalence                  Gender
# 4295               %  Age-adjusted Prevalence                  Gender
# ...              ...                      ...                     ...
# 57152              %         Crude Prevalence                  Gender
# 57207              %  Age-adjusted Prevalence                  Gender
# 57263              %         Crude Prevalence                  Gender
# 57318              %  Age-adjusted Prevalence                  Gender
# 57925              %         Crude Prevalence                 Overall
# 57970              %  Age-adjusted Prevalence                 Overall
# 58025              %         Crude Prevalence                  Gender
# 58075              %  Age-adjusted Prevalence                  Gender
# 58130              %         Crude Prevalence                  Gender
# 58184              %  Age-adjusted Prevalence                  Gender
# 256002             %                  Percent                 Overall
# 516299             %         Crude Prevalence          Race/Ethnicity
# 517072             %         Crude Prevalence                  Gender
# 517073             %         Crude Prevalence                  Gender
# 517074             %         Crude Prevalence                 Overall
# 517075             %         Crude Prevalence          Race/Ethnicity
# 517076             %         Crude Prevalence          Race/Ethnicity
# 517077             %         Crude Prevalence          Race/Ethnicity
# 517078             %         Crude Prevalence          Race/Ethnicity
# 517482             %         Crude Prevalence                  Gender
# 517483             %         Crude Prevalence                  Gender
# 517484             %         Crude Prevalence                 Overall
# 517485             %         Crude Prevalence          Race/Ethnicity
# 517486             %         Crude Prevalence          Race/Ethnicity
# 517487             %         Crude Prevalence          Race/Ethnicity
# 517488             %         Crude Prevalence          Race/Ethnicity
# 517489             %         Crude Prevalence          Race/Ethnicity
# 517599             %         Crude Prevalence                 Overall
# 517655             %         Crude Prevalence                  Gender
# 517711             %         Crude Prevalence                  Gender
#
#                          Stratification1
# 0                                Overall
# 55                               Overall
# 110                                 Male
# 165                                 Male
# 220                               Female
# 275                               Female
# 874                              Overall
# 1201                             Overall
# 1254                             Overall
# 1310                                Male
# 1365                                Male
# 1420                              Female
# 1475                              Female
# 1935                             Overall
# 2125                             Overall
# 2180                                Male
# 2235                                Male
# 2290                              Female
# 2345                              Female
# 2943                             Overall
# 2990                             Overall
# 3045                                Male
# 3100                                Male
# 3155                              Female
# 3210                              Female
# 3806                             Overall
# 4134                             Overall
# 4185                             Overall
# 4240                                Male
# 4295                                Male
# ...                                  ...
# 57152                               Male
# 57207                               Male
# 57263                             Female
# 57318                             Female
# 57925                            Overall
# 57970                            Overall
# 58025                               Male
# 58075                               Male
# 58130                             Female
# 58184                             Female
# 256002                           Overall
# 516299                          Hispanic
# 517072                              Male
# 517073                            Female
# 517074                           Overall
# 517075               White, non-Hispanic
# 517076               Black, non-Hispanic
# 517077  American Indian or Alaska Native
# 517078               Asian, non-Hispanic
# 517482                              Male
# 517483                            Female
# 517484                           Overall
# 517485               White, non-Hispanic
# 517486               Black, non-Hispanic
# 517487                          Hispanic
# 517488  American Indian or Alaska Native
# 517489               Asian, non-Hispanic
# 517599                           Overall
# 517655                              Male
# 517711                            Female
#
# [371 rows x 9 columns]

# %% [markdown]
# Below we uploaded all the tables we created in python, into MySQL for the disease prevalance dataset and causes of death dataset.
#
#
# The rest of the data cleaning and analysis was done on MySQL. The data for disease prevalance was further cleaned in MySQL to only have top ten highest disease prevalence.

# %%
CDI_US_2013.to_sql(name='CDI_2013', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\ricem\Anaconda3\lib\site-packages\pandas\io\sql.py:1144: UserWarning: The provided table name 'CDI_2013' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
pd.read_sql_query('SELECT * FROM CDI_2013', con=engine).head()
# Out:
#    YearStart LocationAbbr   LocationDesc                   Topic  DataValue  \
# 0       2013           US  United States                  Asthma       10.7
# 1       2013           US  United States                  Asthma       11.5
# 2       2013           US  United States  Chronic Kidney Disease      326.3
# 3       2013           US  United States  Chronic Kidney Disease   115877.0
# 4       2013           US  United States  Chronic Kidney Disease      144.8
#
#          DataValueUnit                             DataValueType  \
# 0  cases per 1,000,000                         Age-adjusted Rate
# 1  cases per 1,000,000                                Crude Rate
# 2  cases per 1,000,000  Adjusted by age, sex, race and ethnicity
# 3  cases per 1,000,000                                    Number
# 4  cases per 1,000,000  Adjusted by age, sex, race and ethnicity
#
#   StratificationCategory1 Stratification1
# 0                 Overall         Overall
# 1                 Overall         Overall
# 2                 Overall         Overall
# 3                 Overall         Overall
# 4                 Overall         Overall

# %%
CDI_US_2014.to_sql(name='CDI_2014', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\ricem\Anaconda3\lib\site-packages\pandas\io\sql.py:1144: UserWarning: The provided table name 'CDI_2014' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
pd.read_sql_query('SELECT * FROM CDI_2014', con=engine).head()
# Out:
#    YearStart LocationAbbr   LocationDesc                   Topic  DataValue  \
# 0       2014           US  United States  Chronic Kidney Disease   118014.0
# 1       2014           US  United States  Chronic Kidney Disease      327.5
# 2       2014           US  United States  Chronic Kidney Disease      146.0
# 3       2014           US  United States  Chronic Kidney Disease    52159.0
# 4       2014           US  United States  Cardiovascular Disease       48.9
#
#          DataValueUnit                             DataValueType  \
# 0  cases per 1,000,000                                    Number
# 1  cases per 1,000,000  Adjusted by age, sex, race and ethnicity
# 2  cases per 1,000,000  Adjusted by age, sex, race and ethnicity
# 3  cases per 1,000,000                                    Number
# 4                    %                          Crude Prevalence
#
#   StratificationCategory1 Stratification1
# 0                 Overall         Overall
# 1                 Overall         Overall
# 2                 Overall         Overall
# 3                 Overall         Overall
# 4                  Gender          Female

# %%
CDI_US_2015.to_sql(name='CDI_2015', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\ricem\Anaconda3\lib\site-packages\pandas\io\sql.py:1144: UserWarning: The provided table name 'CDI_2015' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
pd.read_sql_query('SELECT * FROM CDI_2015', con=engine).head()
# Out:
#    YearStart LocationAbbr   LocationDesc    Topic  DataValue DataValueUnit  \
# 0       2015           US  United States  Alcohol       32.8             %
# 1       2015           US  United States  Alcohol       17.7             %
# 2       2015           US  United States  Alcohol       12.6             %
# 3       2015           US  United States  Alcohol       22.0             %
# 4       2015           US  United States  Alcohol       17.0             %
#
#              DataValueType StratificationCategory1 Stratification1
# 0         Crude Prevalence                 Overall         Overall
# 1         Crude Prevalence                 Overall         Overall
# 2  Age-adjusted Prevalence                  Gender          Female
# 3  Age-adjusted Prevalence                  Gender            Male
# 4  Age-adjusted Prevalence                 Overall         Overall

# %%
CDI_US_2016.to_sql(name='CDI_2016', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\ricem\Anaconda3\lib\site-packages\pandas\io\sql.py:1144: UserWarning: The provided table name 'CDI_2016' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
pd.read_sql_query('SELECT * FROM CDI_2016', con=engine).head()
# Out:
#    YearStart LocationAbbr   LocationDesc    Topic  DataValue DataValueUnit  \
# 0       2016           US  United States  Alcohol       16.9             %
# 1       2016           US  United States  Alcohol       17.9             %
# 2       2016           US  United States  Alcohol       21.9             %
# 3       2016           US  United States  Alcohol       22.5             %
# 4       2016           US  United States  Alcohol       12.0             %
#
#              DataValueType StratificationCategory1 Stratification1
# 0         Crude Prevalence                 Overall         Overall
# 1  Age-adjusted Prevalence                 Overall         Overall
# 2         Crude Prevalence                  Gender            Male
# 3  Age-adjusted Prevalence                  Gender            Male
# 4         Crude Prevalence                  Gender          Female

# %%
leading_causes_2013_individual_US.to_sql(name='leadingcauses_2013', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('SELECT * FROM leadingcauses_2013', con=engine).head()
# Out:
#    year           cause_name          state  deaths
# 0  2013                 CLRD  United States  149205
# 1  2013             Diabetes  United States   75578
# 2  2013              Suicide  United States   41149
# 3  2013  Alzheimer's disease  United States   84767
# 4  2013               Cancer  United States  584881

# %%
leading_causes_2014_individual_US.to_sql(name='leadingcauses_2014', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('SELECT * FROM leadingcauses_2014', con=engine).head()
# Out:
#    year               cause_name          state  deaths
# 0  2014  Influenza and pneumonia  United States   55227
# 1  2014            Heart disease  United States  614348
# 2  2014                 Diabetes  United States   76488
# 3  2014                   Stroke  United States  133103
# 4  2014                   Cancer  United States  591700

# %%
leading_causes_2015_individual_US.to_sql(name='leadingcauses_2015', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('SELECT * FROM leadingcauses_2015', con=engine).head()
# Out:
#    year               cause_name          state  deaths
# 0  2015                   Stroke  United States  140323
# 1  2015   Unintentional injuries  United States  146571
# 2  2015  Influenza and pneumonia  United States   57062
# 3  2015           Kidney disease  United States   49959
# 4  2015                     CLRD  United States  155041

# %%
leading_causes_2016_individual_US.to_sql(name='leadingcauses_2016', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('SELECT * FROM leadingcauses_2016', con=engine).head()
# Out:
#    year              cause_name          state  deaths
# 0  2016                  Stroke  United States  142142
# 1  2016                 Suicide  United States   44965
# 2  2016  Unintentional injuries  United States  161374
# 3  2016     Alzheimer's disease  United States  116103
# 4  2016                  Cancer  United States  598038

# %% [markdown]
# ## Chronic Disease Indicators Analysis By State

# %%
# Obtain rows only for the all states
CDI_states = CDI_df.loc[CDI_df['LocationAbbr'] !="US",:]

# Obtain rows only for the years >=2013
CDI_states = CDI_states.loc[CDI_states['YearStart'] >=2013,:]
CDI_states.head(10)
# Out:
#     YearStart LocationAbbr          LocationDesc    Topic  DataValue  \
# 1        2016           AL               Alabama  Alcohol       13.0
# 2        2016           AK                Alaska  Alcohol       18.2
# 3        2016           AZ               Arizona  Alcohol       15.6
# 4        2016           AR              Arkansas  Alcohol       15.0
# 5        2016           CA            California  Alcohol       16.3
# 6        2016           CO              Colorado  Alcohol       19.0
# 7        2016           CT           Connecticut  Alcohol       16.7
# 8        2016           DE              Delaware  Alcohol       17.0
# 9        2016           DC  District of Columbia  Alcohol       25.6
# 10       2016           FL               Florida  Alcohol       15.5
#
#    DataValueUnit     DataValueType StratificationCategory1 Stratification1
# 1              %  Crude Prevalence                 Overall         Overall
# 2              %  Crude Prevalence                 Overall         Overall
# 3              %  Crude Prevalence                 Overall         Overall
# 4              %  Crude Prevalence                 Overall         Overall
# 5              %  Crude Prevalence                 Overall         Overall
# 6              %  Crude Prevalence                 Overall         Overall
# 7              %  Crude Prevalence                 Overall         Overall
# 8              %  Crude Prevalence                 Overall         Overall
# 9              %  Crude Prevalence                 Overall         Overall
# 10             %  Crude Prevalence                 Overall         Overall

# %%
# Separate crude prevalence and age-adjusted prevalence into separate dataframes
CDI_states_crude = CDI_states.loc[CDI_states['DataValueType']=="Crude Prevalence",:]
CDI_states_age_adjusted = CDI_states.loc[CDI_states['DataValueType']=="Age-adjusted Prevalence", :]

# %%
# Separate CDI_states_crude into 3 stratification categories: Overall, Gender Male, Gender Female

# Overall
CDI_states_crude_overall = CDI_states_crude.loc[CDI_states_crude['Stratification1']=="Overall",:]
CDI_states_crude_overall = CDI_states_crude_overall.sort_values(by=['DataValue'], ascending=False)
# Male
CDI_states_crude_male = CDI_states_crude.loc[CDI_states_crude['Stratification1']=="Male",:]
CDI_states_crude_male = CDI_states_crude_male.sort_values(by=['DataValue'], ascending=False)
# Female
CDI_states_crude_female = CDI_states_crude.loc[CDI_states_crude['Stratification1']=="Female",:]
CDI_states_crude_female = CDI_states_crude_female.sort_values(by=['DataValue'], ascending=False)

# %%
## Separate CDI_states_crude_{overall, male, female} by year

# CDI state crude overall (sco)
CDI_sco_2013 = CDI_states_crude_overall.loc[CDI_states_crude_overall['YearStart']==2013,:]
CDI_sco_2014 = CDI_states_crude_overall.loc[CDI_states_crude_overall['YearStart']==2014,:]
CDI_sco_2015 = CDI_states_crude_overall.loc[CDI_states_crude_overall['YearStart']==2015,:]
CDI_sco_2016 = CDI_states_crude_overall.loc[CDI_states_crude_overall['YearStart']==2016,:]

# CDI state crude male (scm)
CDI_scm_2013 = CDI_states_crude_male.loc[CDI_states_crude_male['YearStart']==2013,:]
CDI_scm_2014 = CDI_states_crude_male.loc[CDI_states_crude_male['YearStart']==2014,:]
CDI_scm_2015 = CDI_states_crude_male.loc[CDI_states_crude_male['YearStart']==2015,:]
CDI_scm_2016 = CDI_states_crude_male.loc[CDI_states_crude_male['YearStart']==2016,:]

# CDI state crude female (scf)
CDI_scf_2013 = CDI_states_crude_female.loc[CDI_states_crude_female['YearStart']==2013,:]
CDI_scf_2014 = CDI_states_crude_female.loc[CDI_states_crude_female['YearStart']==2014,:]
CDI_scf_2015 = CDI_states_crude_female.loc[CDI_states_crude_female['YearStart']==2015,:]
CDI_scf_2016 = CDI_states_crude_female.loc[CDI_states_crude_female['YearStart']==2016,:]

# %%
# Separate CDI_states_age_adjusted into 3 stratification categories: Overall, Gender Male, Gender Female, 
# sort by descending prevalence % ('DataValue' column)

# Overall
CDI_states_age_adjusted_overall = CDI_states_age_adjusted.loc[CDI_states_age_adjusted['Stratification1']=="Overall",:]
CDI_states_age_adjusted_overall = CDI_states_age_adjusted_overall.sort_values(by=['DataValue'], ascending=False)
# Male
CDI_states_age_adjusted_male = CDI_states_age_adjusted.loc[CDI_states_age_adjusted['Stratification1']=="Male",:]
CDI_states_age_adjusted_male = CDI_states_age_adjusted_male.sort_values(by=['DataValue'], ascending=False)
# Female
CDI_states_age_adjusted_female = CDI_states_age_adjusted.loc[CDI_states_age_adjusted['Stratification1']=="Female",:]
CDI_states_age_adjusted_female = CDI_states_age_adjusted_female.sort_values(by=['DataValue'], ascending=False)

# %%
## Separate CDI_states_age_adjusted_{overall, male, female} by year

# CDI state crude overall (sco)
CDI_sao_2013 = CDI_states_age_adjusted_overall.loc[CDI_states_age_adjusted_overall['YearStart']==2013,:]
CDI_sao_2014 = CDI_states_age_adjusted_overall.loc[CDI_states_age_adjusted_overall['YearStart']==2014,:]
CDI_sao_2015 = CDI_states_age_adjusted_overall.loc[CDI_states_age_adjusted_overall['YearStart']==2015,:]
CDI_sao_2016 = CDI_states_age_adjusted_overall.loc[CDI_states_age_adjusted_overall['YearStart']==2016,:]

# CDI state crude male (scm)
CDI_sam_2013 = CDI_states_age_adjusted_male.loc[CDI_states_age_adjusted_male['YearStart']==2013,:]
CDI_sam_2014 = CDI_states_age_adjusted_male.loc[CDI_states_age_adjusted_male['YearStart']==2014,:]
CDI_sam_2015 = CDI_states_age_adjusted_male.loc[CDI_states_age_adjusted_male['YearStart']==2015,:]
CDI_sam_2016 = CDI_states_age_adjusted_male.loc[CDI_states_age_adjusted_male['YearStart']==2016,:]

# CDI state crude female (scf)
CDI_saf_2013 = CDI_states_age_adjusted_female.loc[CDI_states_age_adjusted_female['YearStart']==2013,:]
CDI_saf_2014 = CDI_states_age_adjusted_female.loc[CDI_states_age_adjusted_female['YearStart']==2014,:]
CDI_saf_2015 = CDI_states_age_adjusted_female.loc[CDI_states_age_adjusted_female['YearStart']==2015,:]
CDI_saf_2016 = CDI_states_age_adjusted_female.loc[CDI_states_age_adjusted_female['YearStart']==2016,:]

# %% [markdown]
# ## Data Loading into MySQL

# %%
# Load causes by unique states from 2013 to 2016 data
top_10_leading_2013_states_unique.to_sql(name='top_10_2013_unique_states', con=engine, if_exists='replace', index=True)
top_10_leading_2014_states_unique.to_sql(name='top_10_2014_unique_states', con=engine, if_exists='replace', index=True)
top_10_leading_2015_states_unique.to_sql(name='top_10_2015_unique_states', con=engine, if_exists='replace', index=True)
top_10_leading_2016_states_unique.to_sql(name='top_10_2016_unique_states', con=engine, if_exists='replace', index=True)

# %%
# Load states crude overall (sco) from 2013 to 2016 data
CDI_sco_2013.to_sql(name='cdi_sco_2013', con=engine, if_exists='replace', index=True)
CDI_sco_2014.to_sql(name='cdi_sco_2014', con=engine, if_exists='replace', index=True)
CDI_sco_2015.to_sql(name='cdi_sco_2015', con=engine, if_exists='replace', index=True)
CDI_sco_2016.to_sql(name='cdi_sco_2016', con=engine, if_exists='replace', index=True)

# %%
# Load states crude male (scm) from 2013 to 2016 data
CDI_scm_2013.to_sql(name='cdi_scm_2013', con=engine, if_exists='replace', index=True)
CDI_scm_2014.to_sql(name='cdi_scm_2014', con=engine, if_exists='replace', index=True)
CDI_scm_2015.to_sql(name='cdi_scm_2015', con=engine, if_exists='replace', index=True)
CDI_scm_2016.to_sql(name='cdi_scm_2016', con=engine, if_exists='replace', index=True)

# %%
# Load states crude female (scf) from 2013 to 2016 data
CDI_scf_2013.to_sql(name='cdi_scf_2013', con=engine, if_exists='replace', index=True)
CDI_scf_2014.to_sql(name='cdi_scf_2014', con=engine, if_exists='replace', index=True)
CDI_scf_2015.to_sql(name='cdi_scf_2015', con=engine, if_exists='replace', index=True)
CDI_scf_2016.to_sql(name='cdi_scf_2016', con=engine, if_exists='replace', index=True)

# %%
# Load states age-adjusted overall (sao) from 2013 to 2016 data
CDI_sao_2013.to_sql(name='cdi_sao_2013', con=engine, if_exists='replace', index=True)
CDI_sao_2014.to_sql(name='cdi_sao_2014', con=engine, if_exists='replace', index=True)
CDI_sao_2015.to_sql(name='cdi_sao_2015', con=engine, if_exists='replace', index=True)
CDI_sao_2016.to_sql(name='cdi_sao_2016', con=engine, if_exists='replace', index=True)

# %%
# Load states age-adjusted male (sam) from 2013 to 2016 data
CDI_sam_2013.to_sql(name='cdi_sam_2013', con=engine, if_exists='replace', index=True)
CDI_sam_2014.to_sql(name='cdi_sam_2014', con=engine, if_exists='replace', index=True)
CDI_sam_2015.to_sql(name='cdi_sam_2015', con=engine, if_exists='replace', index=True)
CDI_sam_2016.to_sql(name='cdi_sam_2016', con=engine, if_exists='replace', index=True)

# %%
# Load states age-adjusted female (saf) from 2013 to 2016 data
CDI_saf_2013.to_sql(name='cdi_saf_2013', con=engine, if_exists='replace', index=True)
CDI_saf_2014.to_sql(name='cdi_saf_2014', con=engine, if_exists='replace', index=True)
CDI_saf_2015.to_sql(name='cdi_saf_2015', con=engine, if_exists='replace', index=True)
CDI_saf_2016.to_sql(name='cdi_saf_2016', con=engine, if_exists='replace', index=True)

# %% [markdown]
# ## Export files to CSV for backup

# %%
# Export to csv causes by unique states from 2013 to 2016 data
top_10_leading_2013_states_unique.to_csv("top_10_leading_causes_2013_states_unique.csv")
top_10_leading_2014_states_unique.to_csv("top_10_leading_causes_2014_states_unique.csv")
top_10_leading_2015_states_unique.to_csv("top_10_leading_causes_2015_states_unique.csv")
top_10_leading_2016_states_unique.to_csv("top_10_leading_causes_2016_states_unique.csv")

# Export to csv states crude overall (sco) from 2013 to 2016 data
CDI_sco_2013.to_csv("CDI_sco_2013.csv")
CDI_sco_2014.to_csv("CDI_sco_2014.csv")
CDI_sco_2015.to_csv("CDI_sco_2015.csv")
CDI_sco_2016.to_csv("CDI_sco_2016.csv")

# Export to csv states crude male (scm) from 2013 to 2016 data
CDI_scm_2013.to_csv("CDI_scm_2013.csv")
CDI_scm_2014.to_csv("CDI_scm_2014.csv")
CDI_scm_2015.to_csv("CDI_scm_2015.csv")
CDI_scm_2016.to_csv("CDI_scm_2016.csv")

# Export to csv states crude female (scf) from 2013 to 2016 data
CDI_scf_2013.to_csv("CDI_scf_2013.csv")
CDI_scf_2014.to_csv("CDI_scf_2014.csv")
CDI_scf_2015.to_csv("CDI_scf_2015.csv")
CDI_scf_2016.to_csv("CDI_scf_2016.csv")

# Export to csv states age-adjusted overall (sao) from 2013 to 2016 data
CDI_sao_2013.to_csv("CDI_sao_2013.csv")
CDI_sao_2014.to_csv("CDI_sao_2014.csv")
CDI_sao_2015.to_csv("CDI_sao_2015.csv")
CDI_sao_2016.to_csv("CDI_sao_2016.csv")

# Export to csv  states age-adjusted male (sam) from 2013 to 2016 data
CDI_sam_2013.to_csv("CDI_sam_2013.csv")
CDI_sam_2014.to_csv("CDI_sam_2014.csv")
CDI_sam_2015.to_csv("CDI_sam_2015.csv")
CDI_sam_2016.to_csv("CDI_sam_2016.csv")

# Export to csv states age-adjusted female (sam) 2013 to 2016 data
CDI_saf_2013.to_csv("CDI_saf_2013.csv")
CDI_saf_2014.to_csv("CDI_saf_2014.csv")
CDI_saf_2015.to_csv("CDI_saf_2015.csv")
CDI_saf_2016.to_csv("CDI_saf_2016.csv")
